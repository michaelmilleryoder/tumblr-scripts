# %%
import os

data_dirpath = '/usr2/mamille2/tumblr/data/sample1k/'

# %%
import pickle

# Load features and features vectorizer
features_vectorizer_fpath = os.path.join(data_dirpath, 'output', 'feature_vectorizers', 'lr_baseline+exp2_all_feature_vec.pkl')
with open(features_vectorizer_fpath, 'rb') as f:
    features_vectorizer = pickle.load(f)
    
print(len(features_vectorizer.vocabulary_))

features_fpath = os.path.join(data_dirpath, 'output', 'features', 'lr_baseline+exp2_all_features.pkl')
with open(features_fpath, 'rb') as f:
    X_train, y_train, X_test, y_test = pickle.load(f)
    
print(X_train.shape)
# Out:
# 14664
# (641403, 14664)

# %%
# Get exp2 features
exp_features = [f for f in features_vectorizer.vocabulary_ if f.startswith('cat=')]
print(len(exp_features))
exp_features
# Out:
# 355
# ['cat=age,follower_theme=empty age,followee_theme=early-20s',
#  'cat=age,xor_theme',
#  'cat=location,follower_theme=regions,followee_theme=country',
#  'cat=location,xor_theme',
#  'cat=location,follower_theme=regions,followee_theme=europe',
#  'cat=location,follower_theme=americas,followee_theme=country',
#  'cat=location,follower_theme=americas,followee_theme=europe',
#  'cat=location,follower_theme=regions,followee_theme=empty location',
#  'cat=location,follower_theme=americas,followee_theme=empty location',
#  'cat=interests,follower_theme=art,followee_theme=empty interests',
#  'cat=interests,xor_theme',
#  'cat=interests,follower_theme=art,followee_theme=art',
#  'cat=interests,aligned_theme',
#  'cat=relationship status,follower_theme=empty relationship status,followee_theme=attached',
#  'cat=relationship status,xor_theme',
#  'cat=age,follower_theme=empty age,followee_theme=teens',
#  'cat=age,follower_theme=empty age,followee_theme=30+',
#  'cat=gender,follower_theme=empty gender,followee_theme=trans',
#  'cat=gender,xor_theme',
#  'cat=gender,follower_theme=empty gender,followee_theme=male',
#  'cat=interests,follower_theme=empty interests,followee_theme=art',
#  'cat=interests,follower_theme=empty interests,followee_theme=personal care',
#  'cat=pronouns,follower_theme=empty pronouns,followee_theme=he/his',
#  'cat=pronouns,xor_theme',
#  'cat=sexual orientation,follower_theme=empty sexual orientation,followee_theme=queer',
#  'cat=sexual orientation,xor_theme',
#  'cat=sexual orientation,follower_theme=empty sexual orientation,followee_theme=bi/pan',
#  'cat=sexual orientation,follower_theme=empty sexual orientation,followee_theme=lesbian/gay',
#  'cat=ethnicity/nationality,follower_theme=empty ethnicity/nationality,followee_theme=nationality',
#  'cat=ethnicity/nationality,xor_theme',
#  'cat=interests,follower_theme=empty interests,followee_theme=lifestyle',
#  'cat=location,follower_theme=country,followee_theme=empty location',
#  'cat=location,follower_theme=country,followee_theme=country',
#  'cat=location,aligned_theme',
#  'cat=location,follower_theme=country,followee_theme=asia',
#  'cat=location,follower_theme=asia,followee_theme=country',
#  'cat=location,follower_theme=asia,followee_theme=asia',
#  'cat=location,follower_theme=asia,followee_theme=empty location',
#  'cat=gender,follower_theme=male,followee_theme=empty gender',
#  'cat=interests,follower_theme=personal care,followee_theme=personal care',
#  'cat=interests,follower_theme=personal care,followee_theme=empty interests',
#  'cat=location,follower_theme=empty location,followee_theme=regions',
#  'cat=location,follower_theme=empty location,followee_theme=americas',
#  'cat=fandoms,follower_theme=empty fandoms,followee_theme=specific fandom',
#  'cat=fandoms,xor_theme',
#  'cat=fandoms,follower_theme=empty fandoms,followee_theme=game',
#  'cat=fandoms,follower_theme=empty fandoms,followee_theme=literature',
#  'cat=fandoms,follower_theme=empty fandoms,followee_theme=tv/movies',
#  'cat=interests,follower_theme=empty interests,followee_theme=pets',
#  'cat=personality type,follower_theme=empty personality type,followee_theme=hogwarts',
#  'cat=personality type,xor_theme',
#  'cat=ethnicity/nationality,follower_theme=empty ethnicity/nationality,followee_theme=race/ethnicity',
#  'cat=interests,follower_theme=personal care,followee_theme=art',
#  'cat=fandoms,follower_theme=empty fandoms,followee_theme=general fandom',
#  'cat=pronouns,follower_theme=he/his,followee_theme=she/her',
#  'cat=pronouns,follower_theme=neutral,followee_theme=she/her',
#  'cat=personality type,follower_theme=empty personality type,followee_theme=psychological',
#  'cat=pronouns,follower_theme=he/his,followee_theme=neutral',
#  'cat=pronouns,follower_theme=neutral,followee_theme=neutral',
#  'cat=pronouns,aligned_theme',
#  'cat=gender,follower_theme=empty gender,followee_theme=female',
#  'cat=pronouns,follower_theme=empty pronouns,followee_theme=neutral',
#  'cat=age,follower_theme=early-20s,followee_theme=empty age',
#  'cat=age,follower_theme=early-20s,followee_theme=early-20s',
#  'cat=age,aligned_theme',
#  'cat=sexual orientation,follower_theme=straight,followee_theme=queer',
#  'cat=sexual orientation,follower_theme=straight,followee_theme=bi/pan',
#  'cat=sexual orientation,follower_theme=straight,followee_theme=empty sexual orientation',
#  'cat=fandoms,follower_theme=empty fandoms,followee_theme=comics',
#  'cat=age,follower_theme=teens,followee_theme=empty age',
#  'cat=location,follower_theme=cities,followee_theme=empty location',
#  'cat=age,follower_theme=teens,followee_theme=early-20s',
#  'cat=location,follower_theme=cities,followee_theme=country',
#  'cat=location,follower_theme=cities,followee_theme=europe',
#  'cat=age,follower_theme=early-20s,followee_theme=teens',
#  'cat=pronouns,follower_theme=he/his,followee_theme=empty pronouns',
#  'cat=location,follower_theme=empty location,followee_theme=country',
#  'cat=age,follower_theme=empty age,followee_theme=late-20s',
#  'cat=zodiac,follower_theme=empty zodiac,followee_theme=leo',
#  'cat=zodiac,xor_theme',
#  'cat=location,follower_theme=empty location,followee_theme=asia',
#  'cat=pronouns,follower_theme=empty pronouns,followee_theme=she/her',
#  'cat=location,follower_theme=country,followee_theme=regions',
#  'cat=location,follower_theme=country,followee_theme=americas',
#  'cat=location,follower_theme=asia,followee_theme=regions',
#  'cat=location,follower_theme=asia,followee_theme=americas',
#  'cat=location,follower_theme=country,followee_theme=europe',
#  'cat=location,follower_theme=asia,followee_theme=europe',
#  'cat=pronouns,follower_theme=she/her,followee_theme=neutral',
#  'cat=sexual orientation,follower_theme=queer,followee_theme=empty sexual orientation',
#  'cat=sexual orientation,follower_theme=queer,followee_theme=queer',
#  'cat=sexual orientation,aligned_theme',
#  'cat=sexual orientation,follower_theme=queer,followee_theme=lesbian/gay',
#  'cat=gender,follower_theme=female,followee_theme=empty gender',
#  'cat=gender,follower_theme=family,followee_theme=empty gender',
#  'cat=interests,follower_theme=lifestyle,followee_theme=pets',
#  'cat=relationship status,follower_theme=attached,followee_theme=empty relationship status',
#  'cat=interests,follower_theme=lifestyle,followee_theme=empty interests',
#  'cat=sexual orientation,follower_theme=empty sexual orientation,followee_theme=asexual',
#  'cat=age,follower_theme=late-20s,followee_theme=empty age',
#  'cat=age,follower_theme=late-20s,followee_theme=early-20s',
#  'cat=personality type,follower_theme=empty personality type,followee_theme=dnd',
#  'cat=age,follower_theme=teens,followee_theme=teens',
#  'cat=interests,follower_theme=lifestyle,followee_theme=lifestyle',
#  'cat=interests,follower_theme=art,followee_theme=lifestyle',
#  'cat=location,follower_theme=empty location,followee_theme=europe',
#  'cat=interests,follower_theme=lifestyle,followee_theme=art',
#  'cat=interests,follower_theme=pets,followee_theme=art',
#  'cat=interests,follower_theme=pets,followee_theme=lifestyle',
#  'cat=interests,follower_theme=lifestyle,followee_theme=personal care',
#  'cat=interests,follower_theme=pets,followee_theme=personal care',
#  'cat=location,follower_theme=empty location,followee_theme=cities',
#  'cat=fandoms,follower_theme=general fandom,followee_theme=empty fandoms',
#  'cat=fandoms,follower_theme=specific fandom,followee_theme=empty fandoms',
#  'cat=fandoms,follower_theme=comics,followee_theme=empty fandoms',
#  'cat=fandoms,follower_theme=tv/movies,followee_theme=empty fandoms',
#  'cat=age,follower_theme=30+,followee_theme=empty age',
#  'cat=gender,follower_theme=male,followee_theme=male',
#  'cat=gender,aligned_theme',
#  'cat=location,follower_theme=americas,followee_theme=americas',
#  'cat=ethnicity/nationality,follower_theme=nationality,followee_theme=nationality',
#  'cat=ethnicity/nationality,aligned_theme',
#  'cat=fandoms,follower_theme=specific fandom,followee_theme=specific fandom',
#  'cat=fandoms,aligned_theme',
#  'cat=fandoms,follower_theme=specific fandom,followee_theme=literature',
#  'cat=fandoms,follower_theme=specific fandom,followee_theme=tv/movies',
#  'cat=fandoms,follower_theme=game,followee_theme=specific fandom',
#  'cat=fandoms,follower_theme=game,followee_theme=literature',
#  'cat=fandoms,follower_theme=game,followee_theme=tv/movies',
#  'cat=fandoms,follower_theme=comics,followee_theme=specific fandom',
#  'cat=fandoms,follower_theme=comics,followee_theme=literature',
#  'cat=fandoms,follower_theme=comics,followee_theme=tv/movies',
#  'cat=fandoms,follower_theme=literature,followee_theme=specific fandom',
#  'cat=fandoms,follower_theme=literature,followee_theme=literature',
#  'cat=fandoms,follower_theme=literature,followee_theme=tv/movies',
#  'cat=fandoms,follower_theme=tv/movies,followee_theme=specific fandom',
#  'cat=fandoms,follower_theme=tv/movies,followee_theme=literature',
#  'cat=fandoms,follower_theme=tv/movies,followee_theme=tv/movies',
#  'cat=gender,follower_theme=empty gender,followee_theme=cis',
#  'cat=pronouns,follower_theme=she/her,followee_theme=she/her',
#  'cat=ethnicity/nationality,follower_theme=nationality,followee_theme=race/ethnicity',
#  'cat=fandoms,follower_theme=game,followee_theme=empty fandoms',
#  'cat=fandoms,follower_theme=literature,followee_theme=empty fandoms',
#  'cat=sexual orientation,follower_theme=empty sexual orientation,followee_theme=straight',
#  'cat=interests,follower_theme=empty interests,followee_theme=food/drink',
#  'cat=zodiac,follower_theme=empty zodiac,followee_theme=taurus',
#  'cat=location,follower_theme=americas,followee_theme=regions',
#  'cat=relationship status,follower_theme=empty relationship status,followee_theme=single',
#  'cat=roleplay,follower_theme=empty roleplay,followee_theme=general roleplay',
#  'cat=roleplay,xor_theme',
#  'cat=gender,follower_theme=empty gender,followee_theme=family',
#  'cat=pronouns,follower_theme=neutral,followee_theme=empty pronouns',
#  'cat=gender,follower_theme=trans,followee_theme=empty gender',
#  'cat=sexual orientation,follower_theme=bi/pan,followee_theme=empty sexual orientation',
#  'cat=location,follower_theme=regions,followee_theme=regions',
#  'cat=location,follower_theme=regions,followee_theme=americas',
#  'cat=sexual orientation,follower_theme=lesbian/gay,followee_theme=empty sexual orientation',
#  'cat=pronouns,follower_theme=she/her,followee_theme=empty pronouns',
#  'cat=interests,follower_theme=pets,followee_theme=empty interests',
#  'cat=pronouns,follower_theme=she/her,followee_theme=he/his',
#  'cat=fandoms,follower_theme=general fandom,followee_theme=general fandom',
#  'cat=fandoms,follower_theme=specific fandom,followee_theme=general fandom',
#  'cat=fandoms,follower_theme=comics,followee_theme=general fandom',
#  'cat=fandoms,follower_theme=tv/movies,followee_theme=general fandom',
#  'cat=ethnicity/nationality,follower_theme=nationality,followee_theme=empty ethnicity/nationality',
#  'cat=fandoms,follower_theme=specific fandom,followee_theme=ship',
#  'cat=fandoms,follower_theme=game,followee_theme=ship',
#  'cat=fandoms,follower_theme=comics,followee_theme=ship',
#  'cat=fandoms,follower_theme=literature,followee_theme=ship',
#  'cat=fandoms,follower_theme=tv/movies,followee_theme=ship',
#  'cat=zodiac,follower_theme=empty zodiac,followee_theme=virgo',
#  'cat=location,follower_theme=regions,followee_theme=cities',
#  'cat=location,follower_theme=americas,followee_theme=cities',
#  'cat=gender,follower_theme=female,followee_theme=trans',
#  'cat=personality type,follower_theme=hogwarts,followee_theme=empty personality type',
#  'cat=sexual orientation,follower_theme=asexual,followee_theme=queer',
#  'cat=sexual orientation,follower_theme=queer,followee_theme=bi/pan',
#  'cat=sexual orientation,follower_theme=asexual,followee_theme=bi/pan',
#  'cat=gender,follower_theme=female,followee_theme=cis',
#  'cat=personality type,follower_theme=hogwarts,followee_theme=psychological',
#  'cat=sexual orientation,follower_theme=asexual,followee_theme=lesbian/gay',
#  'cat=ethnicity/nationality,follower_theme=race/ethnicity,followee_theme=empty ethnicity/nationality',
#  'cat=personality type,follower_theme=psychological,followee_theme=empty personality type',
#  'cat=age,follower_theme=30+,followee_theme=early-20s',
#  'cat=sexual orientation,follower_theme=bi/pan,followee_theme=queer',
#  'cat=interests,follower_theme=art,followee_theme=pets',
#  'cat=zodiac,follower_theme=empty zodiac,followee_theme=gemini',
#  'cat=zodiac,follower_theme=empty zodiac,followee_theme=cancer',
#  'cat=zodiac,follower_theme=empty zodiac,followee_theme=aries',
#  'cat=interests,follower_theme=empty interests,followee_theme=fitness',
#  'cat=age,follower_theme=30+,followee_theme=teens',
#  'cat=age,follower_theme=early-20s,followee_theme=30+',
#  'cat=location,follower_theme=cities,followee_theme=americas',
#  'cat=age,follower_theme=late-20s,followee_theme=30+',
#  'cat=relationship status,follower_theme=attached,followee_theme=attached',
#  'cat=relationship status,aligned_theme',
#  'cat=fandoms,follower_theme=game,followee_theme=general fandom',
#  'cat=fandoms,follower_theme=literature,followee_theme=general fandom',
#  'cat=fandoms,follower_theme=specific fandom,followee_theme=comics',
#  'cat=fandoms,follower_theme=game,followee_theme=comics',
#  'cat=fandoms,follower_theme=comics,followee_theme=comics',
#  'cat=fandoms,follower_theme=literature,followee_theme=comics',
#  'cat=fandoms,follower_theme=tv/movies,followee_theme=comics',
#  'cat=fandoms,follower_theme=specific fandom,followee_theme=game',
#  'cat=fandoms,follower_theme=game,followee_theme=game',
#  'cat=fandoms,follower_theme=comics,followee_theme=game',
#  'cat=fandoms,follower_theme=literature,followee_theme=game',
#  'cat=fandoms,follower_theme=tv/movies,followee_theme=game',
#  'cat=location,follower_theme=europe,followee_theme=empty location',
#  'cat=ethnicity/nationality,follower_theme=race/ethnicity,followee_theme=nationality',
#  'cat=fandoms,follower_theme=empty fandoms,followee_theme=music',
#  'cat=gender,follower_theme=female,followee_theme=female',
#  'cat=gender,follower_theme=female,followee_theme=family',
#  'cat=gender,follower_theme=family,followee_theme=female',
#  'cat=gender,follower_theme=family,followee_theme=family',
#  'cat=interests,follower_theme=food/drink,followee_theme=art',
#  'cat=interests,follower_theme=food/drink,followee_theme=empty interests',
#  'cat=sexual orientation,follower_theme=asexual,followee_theme=empty sexual orientation',
#  'cat=age,follower_theme=early-20s,followee_theme=late-20s',
#  'cat=age,follower_theme=30+,followee_theme=late-20s',
#  'cat=location,follower_theme=europe,followee_theme=regions',
#  'cat=location,follower_theme=europe,followee_theme=americas',
#  'cat=age,follower_theme=teens,followee_theme=30+',
#  'cat=age,follower_theme=late-20s,followee_theme=late-20s',
#  'cat=location,follower_theme=regions,followee_theme=asia',
#  'cat=location,follower_theme=americas,followee_theme=asia',
#  'cat=interests,follower_theme=art,followee_theme=food/drink',
#  'cat=interests,follower_theme=pets,followee_theme=pets',
#  'cat=roleplay,follower_theme=general roleplay,followee_theme=empty roleplay',
#  'cat=sexual orientation,follower_theme=queer,followee_theme=asexual',
#  'cat=sexual orientation,follower_theme=asexual,followee_theme=asexual',
#  'cat=sexual orientation,follower_theme=bi/pan,followee_theme=bi/pan',
#  'cat=location,follower_theme=empty location,followee_theme=africa',
#  'cat=age,follower_theme=30+,followee_theme=30+',
#  'cat=gender,follower_theme=male,followee_theme=female',
#  'cat=gender,follower_theme=male,followee_theme=family',
#  'cat=pronouns,follower_theme=he/his,followee_theme=he/his',
#  'cat=zodiac,follower_theme=empty zodiac,followee_theme=libra',
#  'cat=pronouns,follower_theme=neutral,followee_theme=he/his',
#  'cat=sexual orientation,follower_theme=straight,followee_theme=straight',
#  'cat=sexual orientation,follower_theme=straight,followee_theme=lesbian/gay',
#  'cat=interests,follower_theme=food/drink,followee_theme=pets',
#  'cat=zodiac,follower_theme=libra,followee_theme=empty zodiac',
#  'cat=fandoms,follower_theme=general fandom,followee_theme=specific fandom',
#  'cat=fandoms,follower_theme=general fandom,followee_theme=comics',
#  'cat=fandoms,follower_theme=general fandom,followee_theme=tv/movies',
#  'cat=interests,follower_theme=lifestyle,followee_theme=food/drink',
#  'cat=location,follower_theme=cities,followee_theme=regions',
#  'cat=zodiac,follower_theme=taurus,followee_theme=empty zodiac',
#  'cat=fandoms,follower_theme=general fandom,followee_theme=game',
#  'cat=gender,follower_theme=cis,followee_theme=trans',
#  'cat=gender,follower_theme=cis,followee_theme=empty gender',
#  'cat=gender,follower_theme=female,followee_theme=male',
#  'cat=gender,follower_theme=trans,followee_theme=male',
#  'cat=location,follower_theme=cities,followee_theme=cities',
#  'cat=location,follower_theme=country,followee_theme=cities',
#  'cat=location,follower_theme=asia,followee_theme=cities',
#  'cat=fandoms,follower_theme=ship,followee_theme=empty fandoms',
#  'cat=interests,follower_theme=personal care,followee_theme=lifestyle',
#  'cat=gender,follower_theme=family,followee_theme=cis',
#  'cat=gender,follower_theme=trans,followee_theme=trans',
#  'cat=location,follower_theme=europe,followee_theme=country',
#  'cat=location,follower_theme=europe,followee_theme=asia',
#  'cat=sexual orientation,follower_theme=lesbian/gay,followee_theme=queer',
#  'cat=sexual orientation,follower_theme=lesbian/gay,followee_theme=bi/pan',
#  'cat=gender,follower_theme=trans,followee_theme=female',
#  'cat=fandoms,follower_theme=general fandom,followee_theme=literature',
#  'cat=gender,follower_theme=cis,followee_theme=male',
#  'cat=fandoms,follower_theme=empty fandoms,followee_theme=ship',
#  'cat=interests,follower_theme=art,followee_theme=personal care',
#  'cat=fandoms,follower_theme=general fandom,followee_theme=music',
#  'cat=personality type,follower_theme=hogwarts,followee_theme=hogwarts',
#  'cat=personality type,aligned_theme',
#  'cat=gender,follower_theme=male,followee_theme=trans',
#  'cat=interests,follower_theme=pets,followee_theme=food/drink',
#  'cat=zodiac,follower_theme=taurus,followee_theme=leo',
#  'cat=location,follower_theme=europe,followee_theme=europe',
#  'cat=location,follower_theme=europe,followee_theme=cities',
#  'cat=zodiac,follower_theme=aries,followee_theme=cancer',
#  'cat=zodiac,follower_theme=aries,followee_theme=virgo',
#  'cat=age,follower_theme=late-20s,followee_theme=teens',
#  'cat=sexual orientation,follower_theme=bi/pan,followee_theme=lesbian/gay',
#  'cat=fandoms,follower_theme=music,followee_theme=empty fandoms',
#  'cat=zodiac,follower_theme=aries,followee_theme=empty zodiac',
#  'cat=fandoms,follower_theme=specific fandom,followee_theme=music',
#  'cat=fandoms,follower_theme=game,followee_theme=music',
#  'cat=age,follower_theme=teens,followee_theme=late-20s',
#  'cat=roleplay,follower_theme=empty roleplay,followee_theme=selective',
#  'cat=zodiac,follower_theme=libra,followee_theme=libra',
#  'cat=zodiac,aligned_theme',
#  'cat=roleplay,follower_theme=general roleplay,followee_theme=general roleplay',
#  'cat=roleplay,aligned_theme',
#  'cat=zodiac,follower_theme=taurus,followee_theme=aries',
#  'cat=relationship status,follower_theme=attached,followee_theme=single',
#  'cat=gender,follower_theme=trans,followee_theme=family',
#  'cat=sexual orientation,follower_theme=bi/pan,followee_theme=asexual',
#  'cat=gender,follower_theme=family,followee_theme=male',
#  'cat=sexual orientation,follower_theme=queer,followee_theme=straight',
#  'cat=sexual orientation,follower_theme=asexual,followee_theme=straight',
#  'cat=interests,follower_theme=fitness,followee_theme=empty interests',
#  'cat=fandoms,follower_theme=music,followee_theme=specific fandom',
#  'cat=fandoms,follower_theme=music,followee_theme=music',
#  'cat=fandoms,follower_theme=literature,followee_theme=music',
#  'cat=fandoms,follower_theme=tv/movies,followee_theme=music',
#  'cat=fandoms,follower_theme=comics,followee_theme=music',
#  'cat=location,follower_theme=cities,followee_theme=asia',
#  'cat=relationship status,follower_theme=single,followee_theme=empty relationship status',
#  'cat=ethnicity/nationality,follower_theme=race/ethnicity,followee_theme=race/ethnicity',
#  'cat=personality type,follower_theme=psychological,followee_theme=psychological',
#  'cat=location,follower_theme=country,followee_theme=africa',
#  'cat=location,follower_theme=americas,followee_theme=africa',
#  'cat=interests,follower_theme=food/drink,followee_theme=food/drink',
#  'cat=interests,follower_theme=food/drink,followee_theme=personal care',
#  'cat=interests,follower_theme=food/drink,followee_theme=lifestyle',
#  'cat=interests,follower_theme=personal care,followee_theme=pets',
#  'cat=personality type,follower_theme=psychological,followee_theme=hogwarts',
#  'cat=fandoms,follower_theme=ship,followee_theme=specific fandom',
#  'cat=fandoms,follower_theme=ship,followee_theme=game',
#  'cat=fandoms,follower_theme=ship,followee_theme=comics',
#  'cat=fandoms,follower_theme=ship,followee_theme=literature',
#  'cat=fandoms,follower_theme=ship,followee_theme=tv/movies',
#  'cat=fandoms,follower_theme=ship,followee_theme=general fandom',
#  'cat=sexual orientation,follower_theme=lesbian/gay,followee_theme=asexual',
#  'cat=sexual orientation,follower_theme=lesbian/gay,followee_theme=lesbian/gay',
#  'cat=interests,follower_theme=personal care,followee_theme=food/drink',
#  'cat=interests,follower_theme=art,followee_theme=fitness',
#  'cat=interests,follower_theme=pets,followee_theme=fitness',
#  'cat=zodiac,follower_theme=cancer,followee_theme=empty zodiac',
#  'cat=fandoms,follower_theme=music,followee_theme=general fandom',
#  'cat=gender,follower_theme=family,followee_theme=trans',
#  'cat=interests,follower_theme=lifestyle,followee_theme=fitness',
#  'cat=gender,follower_theme=cis,followee_theme=cis',
#  'cat=zodiac,follower_theme=taurus,followee_theme=libra',
#  'cat=zodiac,follower_theme=taurus,followee_theme=cancer',
#  'cat=location,follower_theme=asia,followee_theme=africa',
#  'cat=fandoms,follower_theme=general fandom,followee_theme=ship',
#  'cat=sexual orientation,follower_theme=bi/pan,followee_theme=straight',
#  'cat=fandoms,follower_theme=music,followee_theme=comics',
#  'cat=zodiac,follower_theme=leo,followee_theme=empty zodiac',
#  'cat=sexual orientation,follower_theme=lesbian/gay,followee_theme=straight',
#  'cat=roleplay,follower_theme=general roleplay,followee_theme=selective',
#  'cat=personality type,follower_theme=dnd,followee_theme=empty personality type',
#  'cat=location,follower_theme=regions,followee_theme=africa',
#  'cat=location,follower_theme=europe,followee_theme=africa',
#  'cat=relationship status,follower_theme=single,followee_theme=attached',
#  'cat=fandoms,follower_theme=ship,followee_theme=ship',
#  'cat=interests,follower_theme=fitness,followee_theme=art',
#  'cat=personality type,follower_theme=psychological,followee_theme=dnd',
#  'cat=fandoms,follower_theme=ship,followee_theme=music',
#  'cat=gender,follower_theme=trans,followee_theme=cis',
#  'cat=zodiac,follower_theme=cancer,followee_theme=taurus',
#  'cat=zodiac,follower_theme=aries,followee_theme=taurus',
#  'cat=zodiac,follower_theme=cancer,followee_theme=aries',
#  'cat=zodiac,follower_theme=aries,followee_theme=aries',
#  'cat=relationship status,follower_theme=single,followee_theme=single']

# %%
X_train_arr = X_train.A
type(X_train_arr)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

for feature_name in exp_features[:1]:
    feature_index = features_vectorizer.vocabulary_[feature_name]
    print(f"{feature_name}, {feature_index}")
    print(variance_inflation_factor(X_train_arr, feature_index))
# Out:
# cat=age,follower_theme=empty age,followee_theme=early-20s, 12

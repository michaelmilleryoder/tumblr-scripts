# %%
import pandas as pd
import os
import numpy as np
from sklearn.model_selection import train_test_split

from IPython.display import display

data_dirpath = '/usr2/mamille2/tumblr/data'

# %% [markdown]
# # Qualitatively examine non-list annotated descriptions

# %%
# Load annotated descriptions
descs = pd.read_pickle(os.path.join(data_dirpath, 'blog_descriptions_recent100_100posts.pkl'))
print(len(descs))
print(descs.columns)
print()

# Basic stats
cats = ['age', 'location', 'gender', 'sexual orientation', 'pronouns', 
        'personality type', 'ethnicity/nationality', 'relationship status', 'roleplay',
        'fandoms', 'interests', 'weight',
        'sexuality/gender']

outlines = []

for col in cats:
    annotated = sum(descs[col])
    outlines.append([col, annotated, annotated/len(descs) * 100])
#     print(f"{col}: {annotated}\t{annotated/len(descs): .1%}")

# No annotations
any_annote = sum([any(line) for line in list(zip(*[descs[col] for col in cats]))])
no_annote = len(descs) - any_annote
# print()
# print(f'# with no annotations: {no_annote}\t{no_annote/len(descs): .1%}')
outlines.append(['none', no_annote, no_annote/len(descs) * 100])

table = pd.DataFrame(outlines, columns=['category', 'n_instances', 'percentage of descriptions'])\
        .sort_values('percentage of descriptions', ascending=False).reset_index(drop=True)
table
# Out:
# 20266
# Index(['tumblog_id', 'activity_time_epoch', 'tumblr_blog_name',
#        'tumblr_blog_title', 'tumblr_blog_description', 'tumblr_blog_url',
#        'tumblr_blog_theme', 'is_group_blog', 'is_primary', 'is_private',
#        'created_time_epoch', 'updated_time_epoch', 'timezone', 'language',
#        'blog_classifier', 'generated_date', 'parsed_blog_description', 'age',
#        'gender', 'sexual orientation', 'pronouns', 'personality type',
#        'ethnicity/nationality', 'relationship status', 'sexuality/gender',
#        'age_terms', 'gender_terms', 'sexual orientation_terms',
#        'pronouns_terms', 'personality type_terms',
#        'ethnicity/nationality_terms', 'relationship status_terms',
#        'sexuality/gender_terms', 'location_terms', 'location',
#        'roleplay_terms', 'roleplay', 'fandoms_terms', 'fandoms',
#        'interests_terms', 'interests', 'weight_terms', 'weight'],
#       dtype='object')
#                  category  n_instances  percentage of descriptions
# 0   none                   9038         44.596862
# 1   sexuality/gender       4722         23.300109
# 2   age                    3552         17.526892
# 3   interests              3345         16.505477
# 4   pronouns               2489         12.281654
# 5   roleplay               2040         10.066121
# 6   gender                 2038         10.056252
# 7   fandoms                1837         9.064443
# 8   location               1360         6.710747
# 9   sexual orientation     1309         6.459094
# 10  personality type       912          4.500148
# 11  ethnicity/nationality  719          3.547814
# 12  weight                 457          2.255008
# 13  relationship status    426          2.102043

# %% [markdown]
# ## Evaluate quality of annotations

# %%
pd.set_option('display.max_colwidth', -1)

# %%
for col in sorted(cats):
    display(descs[descs[col]==True].sample(30).loc[:, ['parsed_blog_description', col, f'{col}_terms']])
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              parsed_blog_description  \
# 3873753  Quant (/kwänt/, Dutch, meaning "Rogue.") Voshell. 26. Far from home. Lvl 19 | Human | Thief
# 4193718  ADRIANA CLARINGTON; You may know me, you may not know me. That all depends on what you do in your free time. If it's tuning to ESPN, then you're probably used to my mug. Hopefully you know me as #1 Cowboys Fan and, current lover of the one and only Dak Prescott. That's my man right there. For those of you who aren't into the world of sports, I'll do a quick introduction. The name's Adriana Clarington and I'm twenty-six years old. I work for ESPN as a sideline reporter, but in a year or two you can bet your ass I'll be the next Erin Andrews . Texan. That right there is all you need to know. If you want to to make me happy, bring me a Chipotle bowl with a glass of Pinot Noir.  The whole bottle is preferable.
# 1102765  They/Them - 20 - California ~DEPRESSION HOE~
# 2309717  Mel•19•INTJ•'Strayian Sometimes NSFW so tread lightly Sold my soul to fund Big Finish purchases I have too many interests to keep track of Not a shipper anymore, just loves fictional chatacters This blog is a mess (currently in process of cleaning up) (Icon by @sanjism)
# 4133171  23 | US | Straight | Taken | (tough) Lee
# 1226874  I am unaccompanied, I own the depths of my existence ” Can you say the same for yourself? . Angelica Marie Rogers Van-Kamp Twenty-seven. Businesswoman and avid reader. Proud owner of XS, Omnia, Saint James Chateaux & Acqualina Resort. +
# 2949980  18 year old Vampire child with a penchant for lust and cute things 🍼 Also follow my Goth account @xdeadsmeex
# 3943001  M | 22 | Sarasota, FL | 18+, minors will be blocked | This is where I keep my thoughts - mostly private ones.
# 4053005  -ESG | 15 | "He"; "him"; "his". | Italy
# 3808982  18 // he/them // i really love my partner...and kitties. don't forget kitties.
# 2407226  Hello, I'm Kendra and I'm 15 years old |Sw: 150 ~ Cw: 126 ~ Ugw: 100| I do not encourage any illnesses of any kind. This is just a place where I can share my thoughts and feelings and such. None of the pictures are mine unless said otherwise
# 2818143  Haley || 21 || f || they call me halien || TLoZ, Cats, Dragon Age, memes and Nature Visuals for your health || the white tailed deer is my totem animal and i love mythology and im an english major || don't let anyone get in your way of being the best you can be || {icon by kuvshinov ilya}
# 1414809  beckett, 16, Marxist-Leninism-Maoism is bae, guitarist, veggie, dull
# 3620909  15 yo | She/they | Canadian | Dan and Phil blog (if you're interested): teamshibevsthedestroyer
# 3217897  I'm 18, British, 5,6" SW- 17stone CW- 17stone GW1- 15stone GW2- 12stone GW3- 10stone UGW- 9stone
# 1622010  Kyla | 22 | GNC I love my animals. Want to escape capitalism as much as possible and live on a farm. Talk to me about homesteading, raising your own food, plants, dogs, or life. I like to think I'm pretty good to talk to. Currently sharing my life with a Belgian sheepdog named Chianti, a German shepherd puppy named Legion, a magical hoard of cats who put spells on the house, some small furry friends, and my livestock rabbits.
# 3689925  I'm Carley, 19, a photographer, spiritual, I play a lot of video games, and I believe in aliens. Dilly dally, shilly shally, isn't it time you did the forgiving?
# 3833842  23 • michigan grown bisexual • taken • scorpio mostly reblogs unless stated ✨~ I track the tag mariijanexx ~ ✨ • horror • melanie martinez •
# 3764382  chance 17 | taken
# 3627766  ANDREEA NAUM. SHE/HER. AQUÁRIA STUDENT. SIXTEEN. HORSE LOVER. CONVERSATIONALIST. VEGETARIAN.
# 3645091  Maddie|19|lesbian ace|wildlife ecology undergrad
# 3870939  // 20 yrs // Does NOT promote ED // Loves Boys // Loves Girls // Loves Sex// Any questions from my lovely bunnies are welcome 💞//
# 4064840  kenna // 18 // model // not pro-ed
# 2493485  Robin Archer. 22, Pet.
# 2089718  AMIRI . 19 . DA [ NAVIGATION ]
# 3410084  Jessica McKey aka Billie Kay 1/2 of the Iconic Duo with my Girl Cassie Mclntosh aka Peyton Roych 27 years old Bisexual Wresler with NXT. (Roleplaying Blog )
# 2145953  Dylan Cromwell 30 Defense and Water Elemental instructor at RIAP
# 2477553  [she/her pronouns // pansexual // 15 years] "What could go wrong?"
# 2746663  19|| KMN
# 495053   ELAINE NEEVA OLLARD, xix.artista.
#
#           age  age_terms
# 3873753  True  [19]
# 4193718  True  [twenty]
# 1102765  True  [20]
# 2309717  True  [19]
# 4133171  True  [23]
# 1226874  True  [Twenty]
# 2949980  True  [18]
# 3943001  True  [22]
# 4053005  True  [15]
# 3808982  True  [18]
# 2407226  True  [15]
# 2818143  True  [21]
# 1414809  True  [16]
# 3620909  True  [15]
# 3217897  True  [18]
# 1622010  True  [22]
# 3689925  True  [19]
# 3833842  True  [23]
# 3764382  True  [17]
# 3627766  True  [SIXTEEN]
# 3645091  True  [19]
# 3870939  True  [20]
# 4064840  True  [18]
# 2493485  True  [22]
# 2089718  True  [19]
# 3410084  True  [27]
# 2145953  True  [30]
# 2477553  True  [15]
# 2746663  True  [19]
# 495053   True  [xix]
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            parsed_blog_description  \
# 2290585  Skydiving San Diego is North America’s longest operating Skydive business offering the most incredible views of Southern California’s topography.
# 3769897  *TRIGGER WARNING** disclaimer; I do not promote drug use at all. 🇻🇬Australian/ 18/ tauras Just another person with a habit to abuse drugs. Ice princess
# 1413134  18 year old Ashkenazi & Sephardi Jewish Shitposter. Founder of Kahanblr & Member of Toryblr.
# 1216164  Howdy fellas. I uh...like to draw, I'm an English student, and an anti-SJW. That's literally it. Take a glance at my Deviantart
# 1619690  female/19/bi/white - i truly believe pearl jam's "jeremy" is the highest form of art - links
# 3126822  Autumn . 23. Leo/Virgo. Fae, forest, green witch. British as all get-out. Learning, growing, evolving. Aesthetically messy and typically flighty. Do no harm, but take no sh*t.
# 2724101  🌟I'm a star. he taught me that.🌟 Greetings I am a therian of the species european wild cat and red fox and I have the ears to prove it. I don't really care for the construct of gender so call me what you want. Please enjoy this cluster fuck that I call a tumblr.
# 3194458  Berwald. Swedish. Taken by his Romanian.
# 3704406  Hello! I question why you're here but welcome you all the same! I'm the futuristicallycoldfox(because I couldn't resist the tumblr generated irl) but you can call me Frenchfryem. Or French fry. Or fry. Or Em. Or any variation of that or my irl. Honesty, anything is fine so long I know it's me. OH! AND I AM ACE! (ah, how lovely it is to say so)
# 3060501  Watch anime English Dubbed, English Subbed
# 3601311  THE DEATH OF A BACHELOR, SEEMS SO FITTING FOR HAPPILY EVER AFTER, HOW COULD I ASK FOR MORE? independent, private, selecive NEAL CAFFREY from white collar . written by red. tracking # neverlied .
# 3857382  nina torres, 21, victim
# 3571551  Hello, my name is Elder Price! Currently stationed in the...not so lovely...Ugandan mission. I take much pride in my faith and would love to chat about it, so feel free to send me a message.
# 1471175  magnus. 20. swedish. small yet feisty.
# 3766436  ||The twenty-five year old Irish novelist.|| ||"The only way to deal with an unfree world is to become so absolutely free that your very existence is an act of rebellion." ||
# 442558   Katherine “Kat” White . 29 . #506 -Co-Owner of Sable Blanc Fashion - Fashion Blogger / Model always in cahoots with him
# 1311367  Althea Ethelinda Stathakis xxiii, greek princess and fashion lover
# 880621   26. lebanese. *no dms from non-mutuals* HIATUS. EVERYTHINGS ON QUEUE
# 2071170  Supernatural, Destiel, sabriel, cockles trash. Brazilian, 16 yrs, future designer and photographer. Misha Collins is An angel! Fight me.I'm also an artist. So, hope you enjoy!!
# 3745604  Unofficial fan site for the music of southern Connecticut musician and American Idol winner Nick Fradiani, along with music by acts he appears with or enthuses about.
# 2026831  &   SHE'LL BURST   ! like a sun - kissed wave crashing against the shore : like a monochrome painting tearing at the seams & SHE'LL BLOOM like a heart - shaped moon against a pitch - black sky : like a [ PURE SUNLIGHT ] seeping into your skin. &   SHE'LL FADE   ! like a young star dying for the sake of the U N I V E R S E   ! mn .
# 3646611  Lillian Beaucanon | Thirty-One | Paid Escort Painter/Hostess | Viva Las Vegas Shopping sprees in Paris Everything 24 karats Take a look in that mirror Now tell me who's the fairest  Gold jewelry shining so bright Strawberry champagne on ice  Silk sheets and diamonds all white Lucky for you, that's what I like. {part of VIVARP}
# 2093690  NSFW. 18+ only. NOT A PORN BOT 😑 19 yr old bisexual female on an undercover mission to reblog all kinds of kinky shit. Most of the time anyways. I love MAMAMOO and BLACK PINK ❤💕❤💕 I'm obsessed with Harley Quinn and Motoko Kusanagi. I also have a thing for redheads (Triss Merigold to blame) and pigtails (Juliet Starling, I'm blaming you for that one).  I'm also trapped in emotional Shakarian and Shiara hell. I'm not complaining though.  And about ginger snaps...it was a random choice and about the biscuits not that stupid movie jfc.
# 1491131  Nsfw. Not porn, but if youre at work then you really ought to be working instead of looking at my blog :| **NOW IN BATTERY-SAVING BLACK!** They/Them/Mx./Schwa ONLY PLEASE! (This is my main blog)
# 1854359  [Al/Female(she/her)/Scorpio(nov4)/Mexican/ace]only reblogs [Kin:Shay & Paul] (spanish:Al-pensamientoslocos]
# 1211200  .Girl | 14-18 | years old |Capricorn| French | Loves Diego Brando a bit too much | Dialovers | Blood in Roses | Dance with Devils | Likes to make bad jokes e.e | jjba is life (also yoi) | Bisexual and proud to be | Icon by @kay-arts | previously panpan-sama | Hamilton? More like HELL YES
# 846538   it's pronounced black. sugar; spice; and everything nice.
# 2856434  Kathryn | 24 | Cis White Woman | She/Her | Bi | Pagan | Schizotypal Personality Disorder + Obsessions + Major Depressive Disorder | Guinea Pig Enthusiast
# 3572483  +topaz //gryffindor//british mongrel// "the sun loved the moon so much he died everynight just to let it breath"
# 1084625  US Army Vet "Black but not really." |IG: epicpikachu|
#
#          ethnicity/nationality ethnicity/nationality_terms
# 2290585  True                   [Southern]
# 3769897  True                   [Australian]
# 1413134  True                   [Ashkenazi]
# 1216164  True                   [English]
# 1619690  True                   [white]
# 3126822  True                   [British]
# 2724101  True                   [european]
# 3194458  True                   [Swedish, Romanian]
# 3704406  True                   [French]
# 3060501  True                   [English, English]
# 3601311  True                   [white]
# 3857382  True                   [torres]
# 3571551  True                   [Ugandan]
# 1471175  True                   [swedish]
# 3766436  True                   [Irish]
# 442558   True                   [White]
# 1311367  True                   [greek]
# 880621   True                   [lebanese]
# 2071170  True                   [Brazilian]
# 3745604  True                   [southern, American]
# 2026831  True                   [black]
# 3646611  True                   [white]
# 2093690  True                   [BLACK]
# 1491131  True                   [BLACK]
# 1854359  True                   [Mexican, spanish]
# 1211200  True                   [French]
# 846538   True                   [black]
# 2856434  True                   [White]
# 3572483  True                   [british]
# 1084625  True                   [Black]
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              parsed_blog_description  \
# 3361439  My name is Em. I reside in the Twin Cities, and I'm not a huge fan of having responsibility.
# 3264485  indie  rp blog  multi-verse & ship friendlymun & muse: 20+  background artwork by me. d o n ' t   s t e a l.
# 3489915  Hello, I am Hamilton trash. You can call me Mylee! Or Aiglentina, the name I was born with. I just like the name Mylee. Warning: I swear a lot, I can't help it for some reason. Another warning, this is now a mix of Harry Potter and Hamilton. Player of Cards against Hamilton Proud bisexual Tumblr mom is matt10nt This blog is safe for everyone except homo/heterophobes and nazis and trump supporters Please send in an ask! It makes my day. Sorry for long description
# 4149020  I'll put myself back into the narrative.. Welcome. I am Elizabeth Schuyler, wife of Mr. Alexander Hamilton who is never satisfied. Feel free to ask anything you wish. (INDIE ROLEPLAY FOR ELIZA FROM HAMILTON 18+ Read about, Rules and verses before interacting.)
# 2963274  / Irina / Female / Introvert / Pisces / Loves FF (new to the series), Horror (Movies, Games, Books) / Listens To Starset, RED, Hollywood Undead, Imagine Dragons, Papa Roach / Interested In Serial Killers, Creepypastas, Medical History, Plague Doctors, History, Gaming, Video Games, Anime, Manga, Space, Astronomy / I Post Creations I Make On Polyvore And Reblogs / My Acc. On Polyvore Is: Perfex
# 1055285  Mariana. Female. Bored. Equality. This is my general/humour blog. My asthetic ones are: time-does-not-care and cannotdefinebeauty. The 100. X-men. NCIS and other fandoms that i cannot remember, there are too many.
# ...
# 3417555  this blog is to help motivate me. that is all. NSFW I sometimes post science stuff cause I like it. Height: 5'3" // SW: 133 pds // CW:127 pds // UGW: 105 pds
# 1069617  cw: 114 | gw: 108 | ugw: lower? about to binge?
# 3504175  They/them - Aro/ace - Gemini - INTJ - LGBTQIAP+ stuff - Fandom Stuff (DGHDA, SW, Shakespeare) - Politics
# 3396059  I'm not pro ana, not really, but I am desperate to loose weight. HW 210 lbs, SW 195 lbs, CW 199.4 lbs, GW1 185 lbs, GW2 175 lbs, GW3 165 lbs, GW4 155 lbs, ect. , UGW 110 lbs. **no pictures are mine**
# 3225096  18+ ONLY!!! Student✨LA escort✨chicana✨ Fat af✨👻tags: #mywork #me #personal
# 4169522  I don't promote eating disorders Account for personal use only
# 4230648  Just a girl trying to be thin Started my journey 3/10/17 SW:180lbs. CW166lbs GW:130lbs. UWG:125lbs 5'9"/ 175cm I do not promote any eating disorders
# 3849545  15/he/him/pre T     SW: 210   CW: 176   GW: 120    UGW: 100                  If anyone has any questions feel free to shoot a message my way!              This is a proana/anorexia blog so please tread with caution. I'm not going to apologize for having this up because it helps me, so if you have an issue fuck off i have more right wing views than left but im not huge into politics - though i adore social politics and debates.  UK.  .feel free to either shoot me a message or ignore me.
# 3602698  This 21 Day Diet Has 3 Phases that Transform Your Body - Burn 12 to 23 Pounds of Fat!
# 3465108  settled in the suburbs of chicago, ARCADIA UNIVERSITY is home to all kinds of people. from the stoners to the scholars, everyone is welcome here, however, this doesn’t mean that the students are all getting along. though this school might be white and pristine on the outside, what 𝓵𝓲𝓮𝓼 inside is covered in a thin dusting of c o c a i n e on the lockers and a pool full of whiskey in the GYM. — ( ♛ NAV )
# 4024864  HE/HIM I just want to loose weight. SW: 135lbs | CW: 132lbs [x] | GW1: 130lbs [x] | GW2: 120lbs | GW3: 110lbs | UGW: 80lbs
# 2493815  19. 5' 4". gw1: 150 gw2: 130 ugw: 117 this is my 21st century diary i guess
# 2963710  Started in 1st March;  5'3" SW:134lbs CW:119lbs GW:125lbs✅ GW2:115 GW3:110 GW4:100lbs GW5:95lbs GW6:90lbs GW7:85lbs If you want ask me something  I speak english and portuguese
# 4067711  ~sara ~ 15 ~ this blog is for me :) hw: 150 sw: 145 cw: 127.4 gw1: 125 gw2: 120 ugw: 115 h: 5'5
# 3808346  🌸TRIGGER WARNING 🌸 18 | 5' 1/2 | Hw : 150 lb | Cw: 139| UGW: 105 lb |
# 259196   The picture is not me. Content may be triggering. Some things may be NSFW. I don't advocate anything. Don't ask for advice because I won't give you any. This blog is as private as tumblr would let me make it. This blog is solely for me. HW: 195 LW: 130 CW: 182 GW1: 175 GW2: 165 GW3: 155 GW4: 145 GW6: 135
# 4164639  Sierra • 5'6" • SW/HW: 174 Ibs • CW: 151.6 Ibs • [✓] GW1: 165 Ibs • [✓] GW2: 155 Ibs • [] GW3: 145 Ibs • [] GW4: 135 Ibs • [] GW5: 125 Ibs • [] GW6: 115 Ibs • [] UGW: 100 Ibs •
#
#          weight  \
# 3927602  True
# 3604542  True
# 3663268  True
# 3806645  True
# 3629220  True
# 2775979  True
# 2509540  True
# 1601211  True
# 2517103  True
# 3719011  True
# 4203642  True
# 3871242  True
# 3753598  True
# 3417555  True
# 1069617  True
# 3504175  True
# 3396059  True
# 3225096  True
# 4169522  True
# 4230648  True
# 3849545  True
# 3602698  True
# 3465108  True
# 4024864  True
# 2493815  True
# 2963710  True
# 4067711  True
# 3808346  True
# 259196   True
# 4164639  True
#
#                                                                              weight_terms
# 3927602  [SW, CW, GW1]
# 3604542  [SW, lbs, CW, lbs, GW, lbs, lbs, LW, lbs]
# 3663268  [HW, SW, lbs, CW, GW1]
# 3806645  [WEIGHT]
# 3629220  [eating disorders]
# 2775979  [SW, CW, GW]
# 2509540  [SW, CW, GW]
# 1601211  [Anorexia]
# 2517103  [Fat]
# 3719011  [anorexia, weight, CW, GW1, GW2, GW3]
# 4203642  [HW, CW, GW1, GW2]
# 3871242  [SW, CW]
# 3753598  [ana, Hw, Sw, Cw, Gw1, Gw2, ana]
# 3417555  [SW, CW]
# 1069617  [cw, gw]
# 3504175  [SW]
# 3396059  [ana, weight, HW, lbs, SW, lbs, CW, lbs, GW1, lbs, GW2, lbs, GW3, lbs, lbs, lbs]
# 3225096  [Fat]
# 4169522  [eating disorders]
# 4230648  [thin, SW, GW, eating disorders]
# 3849545  [SW, CW, GW, anorexia]
# 3602698  [Pounds, Fat]
# 3465108  [thin]
# 4024864  [weight, SW, CW, GW1, GW2, GW3]
# 2493815  [gw1, gw2]
# 2963710  [SW, CW, GW, GW2, GW3]
# 4067711  [hw, sw, cw, gw1, gw2]
# 3808346  [Hw, lb, Cw, lb]
# 259196   [HW, LW, CW, GW1, GW2, GW3]
# 4164639  [SW, HW, CW, GW1, GW2, GW3]

# %%
len(cats)
# Out:
# 13

# %% [markdown]
# # Evaluate errors in comparison to hand-annotated

# %%
# Load data
# data = pd.read_pickle(os.path.join(data_dirpath, 'blog_descriptions_1000sample_train.pkl'))
data = pd.read_pickle(os.path.join(data_dirpath, 'blog_descriptions_1000sample_test.pkl'))

# Normalize to booleans
with open(os.path.join(data_dirpath, 'identity_categories.txt')) as f:
    cats = f.read().splitlines()
    
for col in cats:
    data[col] = [a==1 for a in data[col]]

pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_rows', -1)

cat = 'fandoms'

print('False positives:')
false_positives = data[(data[cat]==False) & (data[f'{cat}_pred']==True)]
display(data.loc[false_positives.index, ['tumblog_id', 'parsed_blog_description', f'{cat}_terms']])

# print('False negatives:')
# false_negatives = data[(data[cat]==True) & (data[f'{cat}_pred']==False)]
# display(data.loc[false_negatives.index, ['tumblog_id', 'parsed_blog_description', f'{cat}_terms']])
# Out:
# False positives:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     700                 type_pprinters=self.type_printers,
#     701                 deferred_pprinters=self.deferred_printers)
# --> 702             printer.pretty(obj)
#     703             printer.flush()
#     704             return stream.getvalue()
#
# ~/anaconda3/lib/python3.6/site-packages/IPython/lib/pretty.py in pretty(self, obj)
#     393                             if callable(meth):
#     394                                 return meth(obj, self, cycle)
# --> 395             return _default_pprint(obj, self, cycle)
#     396         finally:
#     397             self.end_group()
#
# ~/anaconda3/lib/python3.6/site-packages/IPython/lib/pretty.py in _default_pprint(obj, p, cycle)
#     508     if _safe_getattr(klass, '__repr__', None) is not object.__repr__:
#     509         # A user-provided repr. Find newlines and replace them with p.break_()
# --> 510         _repr_pprint(obj, p, cycle)
#     511         return
#     512     p.begin_group(1, '<')
#
# ~/anaconda3/lib/python3.6/site-packages/IPython/lib/pretty.py in _repr_pprint(obj, p, cycle)
#     699     """A pprint that just redirects to the normal repr function."""
#     700     # Find newlines and replace them with p.break_()
# --> 701     output = repr(obj)
#     702     for idx,output_line in enumerate(output.splitlines()):
#     703         if idx:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/base.py in __repr__(self)
#      78         Yields Bytestring in Py2, Unicode String in py3.
#      79         """
# ---> 80         return str(self)
#      81
#      82
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/base.py in __str__(self)
#      57
#      58         if compat.PY3:
# ---> 59             return self.__unicode__()
#      60         return self.__bytes__()
#      61
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __unicode__(self)
#     634             width = None
#     635         self.to_string(buf=buf, max_rows=max_rows, max_cols=max_cols,
# --> 636                        line_width=width, show_dimensions=show_dimensions)
#     637
#     638         return buf.getvalue()
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in to_string(self, buf, columns, col_space, header, index, na_rep, formatters, float_format, sparsify, index_names, justify, line_width, max_rows, max_cols, show_dimensions)
#    1673                                            max_cols=max_cols,
#    1674                                            show_dimensions=show_dimensions)
# -> 1675         formatter.to_string()
#    1676
#    1677         if buf is None:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/formats/format.py in to_string(self)
#     601             elif (not isinstance(self.max_cols, int) or
#     602                     self.max_cols > 0):  # need to wrap around
# --> 603                 text = self._join_multiline(*strcols)
#     604             else:  # max_cols == 0. Try to fit frame to terminal
#     605                 text = self.adj.adjoin(1, *strcols).split('\n')
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/formats/format.py in _join_multiline(self, *strcols)
#     671                 else:
#     672                     row.append([' '] * nrows)
# --> 673             str_lst.append(self.adj.adjoin(adjoin_width, *row))
#     674             st = ed
#     675         return '\n\n'.join(str_lst)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/formats/format.py in adjoin(self, space, *lists, **kwargs)
#     301     def adjoin(self, space, *lists, **kwargs):
#     302         return adjoin(space, *lists, strlen=self.len,
# --> 303                       justfunc=self.justify, **kwargs)
#     304
#     305
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/formats/printing.py in adjoin(space, *lists, **kwargs)
#      33     lengths = [max(map(strlen, x)) + space for x in lists[:-1]]
#      34     # not the last one
# ---> 35     lengths.append(max(map(len, lists[-1])))
#      36     maxLen = max(map(len, lists))
#      37     for i, lst in enumerate(lists):
#
# ValueError: max() arg is an empty sequence
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>tumblog_id</th>
#       <th>parsed_blog_description</th>
#       <th>fandoms_terms</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>408</th>
#       <td>337981527</td>
#       <td>Celeste Creator and CEO of Celestialbodiez. Former WWE Diva's champion. Currently still breaking hearts…and SOME faces. Multiship | Multiverse | NSFW Friendly | 20+ | Semi Selective</td>
#       <td>[WWE, Multiship, Multiverse]</td>
#     </tr>
#     <tr>
#       <th>453</th>
#       <td>240787984</td>
#       <td>shaladin shippers will be blocked</td>
#       <td>[shaladin, shipper]</td>
#     </tr>
#     <tr>
#       <th>289</th>
#       <td>334343712</td>
#       <td>Indie . Pri . Selective . Canon Divergant. Penned by Aku . EST 2/2/17</td>
#       <td>[Canon]</td>
#     </tr>
#     <tr>
#       <th>347</th>
#       <td>331412837</td>
#       <td>A Forum Managed by UConn's First-Year Writing Course on Adaptation and the Canon, Spring 2017</td>
#       <td>[Canon]</td>
#     </tr>
#     <tr>
#       <th>228</th>
#       <td>311957840</td>
#       <td>Let me tell you what I wish I'd known, when I was young and dreamed of glory. You have no control, who lives who died, who tells your story. And I know that we can win, I know that greatness lies in you. Just remember from here on in: History has it's eyes on you. Multimuse||Multifandom||Canon/OC Roleplay Blog Written by Eliza Be Warned there are Doppelgangers on this blog</td>
#       <td>[fandom, Canon]</td>
#     </tr>
#     <tr>
#       <th>453</th>
#       <td>240787984</td>
#       <td>shaladin shippers will be blocked</td>
#       <td>[shaladin, shipper]</td>
#     </tr>
#     <tr>
#       <th>289</th>
#       <td>334343712</td>
#       <td>Indie . Pri . Selective . Canon Divergant. Penned by Aku . EST 2/2/17</td>
#       <td>[Canon]</td>
#     </tr>
#     <tr>
#       <th>347</th>
#       <td>331412837</td>
#       <td>A Forum Managed by UConn's First-Year Writing Course on Adaptation and the Canon, Spring 2017</td>
#       <td>[Canon]</td>
#     </tr>
#     <tr>
#       <th>228</th>
#       <td>311957840</td>
#       <td>Let me tell you what I wish I'd known, when I was young and dreamed of glory. You have no control, who lives who died, who tells your story. And I know that we can win, I know that greatness lies in you. Just remember from here on in: History has it's eyes on you. Multimuse||Multifandom||Canon/OC Roleplay Blog Written by Eliza Be Warned there are Doppelgangers on this blog</td>
#       <td>[fandom, Canon]</td>
#     </tr>
#     <tr>
#       <th>898</th>
#       <td>266332716</td>
#       <td>Call me Jazz. She/Her. 17 // CA. A fan of memes and the duo from Ohio.</td>
#       <td>[fan]</td>
#     </tr>
#   </tbody>
# </table>
# <p>6 rows × 3 columns</p>
# </div>

# %% [markdown]
# # Split 1000 annotated into train/test

# %%
data = pd.read_csv(os.path.join(data_dirpath, 'blog_descriptions_1000sample.csv'))
print(len(data))

train, test = train_test_split(data, test_size=0.2, random_state=7)

train.to_pickle(os.path.join(data_dirpath, 'blog_descriptions_1000sample_train.pkl'))
test.to_pickle(os.path.join(data_dirpath, 'blog_descriptions_1000sample_test.pkl'))
# Out:
# 1000

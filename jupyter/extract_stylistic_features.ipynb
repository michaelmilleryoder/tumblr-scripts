# %% [markdown]
# # Check BTS data

# %%
data.shape
# Out:
# (575920, 27)

# %%
pd.set_option('display.max_colwidth', -1)

# %%
data['post_body'].sample(10)
# Out:
# 4226213     minhyukslatina : jimin ’s   thighs are so thick , but you know what else is thick ? dats rite , his heart                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            ...
# 4042429     request # 23 . bts texts : jimin is being needy . request from anonymous :    “ can you do a fake text where a member is being needy af ? ”                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ...
# 2868364     featuring : daddy!yoongi , you warnings : dd / lg themes written by : admin v i want to break your spell with my cuddles / you seem like an angel with no wings listen   and read ! xoxo admin v something about daddy ’s hands are magical . they must be , for the very second the soft skin softly envelops you in them , a faint whisper of peace and quiet begins to slip into your mind . life just fades away . angry words and upset thoughts are merely a figment of your imagination , yes they are , as the hands continue to travel you . they work their way up and down . palms smoothing over your back , fingertips massaging your scalp . daddy ’s hands brush downwards in your strands of hair as he pulls you back to look up at him , and you do n’t think you have ever been happier . the tears of sorrow in your eyes slowly begin to become tears of happiness . daddy ’s hands are special . they are n’t particularly big by any means , but against your body they are . and others might not think much of daddy ’s hands , but you know that they are fine tuned in a way that the rest of the worlds’ will never be able to . daddy ’s hands are ones that can spin out melodies of the gods and pen down poetry of the muses . they are also ones that make you forget the rest of the world .   just a simple tap of the pad of his finger onto you is like a droplet of water in a lake , its effect rippling throughout you . daddy starts with your hands , intertwines them with his . perfectly pink , glossy nails and cuticles that are curved in the most immaculate crescent moons . your eyes follow daddy ’s hands as they move upwards . sometimes his hands graze against your skin in certain spots — in other places he sensually massages , kneads the flesh of your shoulders and places that are wound up from the stress of the day ’s work .   every horrible thing that happened during the day eases out , is sent out the house with some extra leftover dinner and the door shut firmly in its face .   daddy ’s hands still yet continue their path along your body . they soothe over your breasts , rest at your waist . daddy stops there , glances up at you . is it working ? he thinks . are you settling down ? are you finally going to that spot in your mind where the only person who has to worry about adult life is him ? not you ? your eyes shut and the tiniest smile folds upwards and daddy stops , chuckles to himself .   his hands oh - so softly , as if there is a cushion of air under his limbs , lift away from your waist . instead , they are placed on each of your cheeks , his fingertips brushing your eyelashes and his palms gently cupping your face . daddy leans down—   it ’s not just daddy ’s hands that are magical , too .   thank you for requesting , anon ! if you have any requests , make sure to send them over to our jiminsbyuns ask box – we are open for anything ! thank you all for reading ! xoxo   admin v                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ...
# 2273962     text / social media / narrative series ||   soulmate   & college au previous part   |   next part    in the works linked masterlist “ according to greek mythology , humans were originally created with four arms , four legs and a head with two faces . fearing their power , zeus split them into two separate parts , condemning them to spend their lives in search of their other halves . ”    ― plato , the symposium credit goes to the incredible   @789cream   for creating this beautiful   moodboard   for my series . thanks again !   “ i think we need to talk , ” you say , doing your best to keep your voice steady as you take a seat next to jimin on the couch , maintaining a safe distance .   “ yes , i guess we   do . ”   “ but let ’s handle this like grownups , ” you add , meeting jimin ’s eyes for the first time since you entered the dark living room .   the curtains are drawn , allowing almost no daylight to come in through the high windows , and jimin looks like he has n’t left this sofa in   days . his hair is disheveled , and so are his clothes which he must have borrowed from taehyung , judging by their size . it pains you to see him like this , cheeks hollow , eyes red and puffy , most likely from crying . but this time , you wo n’t shy away from performing this cut which simply   has   to be made . right here and right now . pairing   you x   soulmate !   yoongi you x jimin word count 4.783 ‘ siblings’ , according to age : namjoon , jimin ,   y / n , taehyung ( you grew up living in the same foster home as implied in earlier parts of this series )   fluff ,   angst ❗ ️   warnings   ❗ ️ mentions of abusive relationships , drinking , physically and emotionally abusive behavior and self - destructive behavior ‼️ trigger warning   ‼️ mentions of   cutting / self - harm    disclaimer :    i , in no way , aim to romanticize , endorse or condone cutting or any kind of self - destructive behavior as a coping mechanism . if you are prone to such tendencies ,   read this chapter at your own risk . in case you are currently considering to harm yourself or are / have been dealing with similar issues , never hesitate to talk to me or seek out professional help . there are skilled people who can help you get rid of such toxic habits . you are strong and you can fight it . i believe in you . 💖 previously , on ‘ linked’ …   eventually , after   years   of successfully having avoided it , you have come across your soulmate . an ominous stranger of whom you know no more than the back of his head , his phone number and that he works as a part - time barista at your ( former ) favorite coffee shop . having been pressured by a friend into contacting him , things start to get complicated . because your heart already belongs to another . and , haunted by the ghosts of your past , the last thing you want is for your soul to find its one , true ,   destined   mate . after texting back and forth for days with the man only known to you as your ‘ soulmate ’ , you are forced to break contact since he is starting to get too close and your boyfriend jimin is anything but pleased with that . when your paths , however , cross , the ominous ‘ suga ’ , as he calls himself , refrains from revealing his true identity to you - which would mean an instant link of souls and the end of his torture -   and , instead , is set on making his way into your life the   right   way . a fateful accident at your workplace is followed by a visit to the emergency room and a falling out with your boyfriend , jimin , leading you to turn to a virtual   stranger   for comfort . a whole day you spend with the mysterious suga who ’s familiarity is an enigma to you . until his   true   identity is revealed and things quickly turn sour , starting to snowball from then on , the events sending you into a rapid downward spiral … chapter 19 “ come on , nana . you   know   me . it ’s   me , yoongi , tae ’s   friend . let me in , please . i need to speak to jimin . "    by now  ...
# 3177004     hey rb this with ur fave variety show bts has appeared on                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            ...
# 16989860    ygcutie : jungkook got overworked from performing for his fans because he knows he can?t see them much and people sexualized or mocked his pain . he looked beautiful in the love yourself wonder video but people started mocking him and comparing him to a dog . he can?t even fucking breathe smile or just exist without someone saying something about him not having any lips . ? this is daily .. he worked hard on a whole choreography for a song made for his hyungs and got mocked for that . he?s been labeled a annoying spoiled brat or a fuckboy asshole so much to the point where some new fans actually think he?s really like that when he?s not . he couldn?t have a solo stage ( rainism ) in peace because some people actually got angry and started hate accounts and even tried to start a petition to get him kick him out of bts for getting too much attention compared to the other members . if y all want to sit here and ignore or downplay all the hate and the harsh mocking when it comes to jungkook fine but i?m sick of it . i?ve seen too much of it and i?ll keep speaking on it until this fandom see?s jungkook as more than a meme a joke a punching bag or a object .                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   ...
# 11668913    pairing : jungkook x reader genre : fluff , angst , late night au ( ? ) word count : 11k   a / n : this took way longer than i expected and thank you   @drowsymochi   for being so sweet and helping me out with this fic ! 💜 💘 💝 💗 🌈 🦄 ~~ he was like the first rays of the sun , so bright and so beautiful as it shone over the horizon .   in that fleeting moment , it looks at the moon and kisses her gently with its gleam , so gently she almost misses it . almost .   but when she looks up at the sun , he ’s gone . the first time you met him was in the convenience store down the road . your father had just passed away not long ago and your only company became your mom , hence the immediate decision to shuck school dorms to seek solace from your mother .   at first it had been difficult . with such an important loved one suddenly gone , you and your mom felt caged in a world of depression , with your tear stained pillow being your only other companion . both of you were struggling to get by ; student loans were piling up at your mailbox and you found yourself working countless part - time jobs atop the merciless schedule of a med student .   but the comfort of time slowly kicks in and soothes the missing place in your life with another figure . ~ 12:43 — the perfect time to grab a late night snack in place of your thriftily selected dinner ( a rotten banana found on the kitchen counter ) . your stomach rumbles as you shut your anatomy textbook with a satisfied “ slam ” and pack up all the med tools you need for the following day . your decision to forgo dinner hits you with a karmic wave of regret , but thank goodness the convenience store two streets down was open 24/7 . as you whistle the tune of the cowboy bebop theme song and dangle your keys on the tip of your fingers , you enter the convenience store with a dramatic spin and turn to face your self - acclaimed seat by the window , only to find it occupied … with a male ? a male wearing an unnecessary leather jacket and questionably tight jeans which had way too many holes to count ? you scoff ungratefully - who wears leather jackets in mid may ? was n’t he prepared to melt into a puddle ? and most importantly , who steals your seat you had so proudly self - proclaimed as yours ? but you ca n’t help your eyes as they wander to his thighs that were unbelievably beautiful , with rough denim wrapping around his thick muscles . you stiffen when you spot the veins warping along his arm , trailing down beside his elbow , and you are positive you release the tiniest gasp from the back of your throat . under your scrutiny , he just stares back at you with warm brown eyes and raises an eyebrow at you curiously .   did an awfully muscular and good looking guy catch you checking him out as if you ’ve never seen a hot guy in your life before ? you hate to admit — you ’ve seen your share of hot dudes , but this guy was smoking .   you clear your throat and quickly avert your eyes to the nearest available object , face turning red in an instant as you avoid having to deal with any unneeded social contact . you saunter to the instant ramen you ’ve been craving for and resume your cowboy bebop jam session as if nothing embarrassing had just happened . “ is that the cowboy bebop opening song ? ” a soft , melodious voice captured your attention as you whip your head around from the counter .   “ uhm … yeah . ” it ’s the hot dude you were checking out earlier , except he is now stuffing steamy noodles in his face like the antagonistic giant monsters they show in cartoons , swallowing up everything in their way .   “ oh yeeees , goob showw . ” he adds on enthusiastically , cheeks still puffed from his mouthful of noodles . you grin , glad that someone , regardless of his eating habits , was finally hitting your element .   settling down beside him and closing the cap of your instant ramen to make it heat up faster , you see the guy wipe his mouth with the back of his hand and ask , “ why  ...
# 14437962    where s that fucking twitter thread of somebody catfishing a guy as jimin                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            ...
# 4435213     [ yoongi after his stylist could n’t show up before a performance ]   yoongi :   steam curls hair right ?   stylist :   yoongi , i ’ll curl your hair . come sit down , steam does n’t curl hair .   yoongi :   stranger is talking to me . nope . steam your curling my hair .                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ...
# 17022254    “ whatcha lookin’ at , pretty boy ? ” the male asked gruffly without looking at him , smoke coming from his lips in uncharacteristically beautiful curls , framing his face in the dim lighting . jungkook looked away , hoping that the darkness of the alleyway was enough to overpower the light of the flickering neon signs and keep his face hidden under his hood . “ nothing . ” he replied , casting his eyes down momentarily only to slowly drag them back up , chin held straight . the mysterious man let out a fit of laughter , tilting his head back . it was the laughter of a broken man , rebuilt only to be broken again . insanity laced the sound — like many of the things in the world — giving it a bittersweet timbre . he hummed , snapping his head forward again and looking jungkook straight in the eye . jungkook ’s breath caught at the back of his throat . he brought his index and middle fingers to his lips , cigarette held between them familiarly , and took another slow , relaxed drag , the end glowing a warm orange . “ do n’t b’lieve ya , kiddo . ” he breathed out , his words seeming to birth the smoke . jungkook could n’t draw his gaze away , no matter how hard he tried . “ then do n’t . ” he replied simply , against his better judgement , sounding a little breathless in his own ears . the male narrowed his fox - like eyes at jungkook , allowing a few more seconds to pass with their gazes interlocked . then , with a final drag and its following curls of smoke , he dropped the cigarette to the ground , crushing it under his foot without looking . “ th’ name ’s yoongi . min yoongi . ” he finally voiced after the suffocating silence , waiting for a response . it took jungkook a moment to formulate one . “ i- i ’m … jeon jungkook . ” something i got inspiration for in spanish class , i might turn it into an actual fic ? thoughts ?                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ...
# Name: post_body, dtype: object

# %% [markdown]
# # Process data

# %% [markdown]
# ## Concatenate posts

# %%
import pandas as pd
import csv
import os
from tqdm import tqdm_notebook as tqdm

community = 'bts'
data_dirpath = f'../../data/{community}_posts'

posts = []
for fname in tqdm(os.listdir(data_dirpath)):
    fpath = os.path.join(data_dirpath, fname)
    try:
        part = pd.read_csv(fpath, sep='\t')
    except:
        part = pd.read_csv(fpath, sep='\t', engine='python', quoting=csv.QUOTE_NONE, error_bad_lines=False, warn_bad_lines=False)
    posts.extend(part.values.tolist())
# Out:
# HBox(children=(IntProgress(value=0, max=1542), HTML(value='')))
# Skipping line 10553: Expected 25 fields in line 10553, saw 71
# Skipping line 10554: Expected 25 fields in line 10554, saw 68
# Skipping line 21583: Expected 25 fields in line 21583, saw 27
# Skipping line 2119: Expected 25 fields in line 2119, saw 26
# Skipping line 2121: Expected 25 fields in line 2121, saw 26
# Skipping line 3161: Expected 25 fields in line 3161, saw 30
# Skipping line 5221: Expected 25 fields in line 5221, saw 30
# Skipping line 5222: Expected 25 fields in line 5222, saw 30
# Skipping line 5223: Expected 25 fields in line 5223, saw 30
# Skipping line 5227: Expected 25 fields in line 5227, saw 30
# Skipping line 5234: Expected 25 fields in line 5234, saw 30
# Skipping line 12004: Expected 25 fields in line 12004, saw 77
# Skipping line 12005: Expected 25 fields in line 12005, saw 77
# Skipping line 13164: Expected 25 fields in line 13164, saw 26
# Skipping line 13289: Expected 25 fields in line 13289, saw 51
# Skipping line 13290: Expected 25 fields in line 13290, saw 51
# Skipping line 13291: Expected 25 fields in line 13291, saw 51
# Skipping line 1736: Expected 25 fields in line 1736, saw 259
# Skipping line 2000: Expected 25 fields in line 2000, saw 259
# Skipping line 2021: Expected 25 fields in line 2021, saw 41
# Skipping line 2024: Expected 25 fields in line 2024, saw 36
# Skipping line 2091: Expected 25 fields in line 2091, saw 61
# Skipping line 2113: Expected 25 fields in line 2113, saw 61
# Skipping line 4395: Expected 25 fields in line 4395, saw 27
# Skipping line 15259: Expected 25 fields in line 15259, saw 26
# Skipping line 15282: Expected 25 fields in line 15282, saw 26
# Skipping line 14331: Expected 25 fields in line 14331, saw 26
# Skipping line 14332: Expected 25 fields in line 14332, saw 26
# Skipping line 14335: Expected 25 fields in line 14335, saw 26
# Skipping line 14336: Expected 25 fields in line 14336, saw 26
# Skipping line 4099: field larger than field limit (131072)
# Skipping line 4102: field larger than field limit (131072)
# Skipping line 2927: Expected 25 fields in line 2927, saw 52
# Skipping line 3282: Expected 25 fields in line 3282, saw 76
# Skipping line 7712: Expected 25 fields in line 7712, saw 203
# Skipping line 7714: Expected 25 fields in line 7714, saw 203
# Skipping line 11691: Expected 25 fields in line 11691, saw 186
# Skipping line 34684: Expected 25 fields in line 34684, saw 76
# Skipping line 36148: Expected 25 fields in line 36148, saw 29
# Skipping line 849: field larger than field limit (131072)
# Skipping line 5165: Expected 25 fields in line 5165, saw 97
# Skipping line 5166: Expected 25 fields in line 5166, saw 97
# Skipping line 5168: Expected 25 fields in line 5168, saw 97
# Skipping line 5169: Expected 25 fields in line 5169, saw 97
# Skipping line 5172: Expected 25 fields in line 5172, saw 155
# Skipping line 5173: Expected 25 fields in line 5173, saw 155
# Skipping line 5177: Expected 25 fields in line 5177, saw 129
# Skipping line 5178: Expected 25 fields in line 5178, saw 129
# Skipping line 5181: Expected 25 fields in line 5181, saw 119
# Skipping line 5182: Expected 25 fields in line 5182, saw 119
# Skipping line 5193: Expected 25 fields in line 5193, saw 30
# Skipping line 5194: Expected 25 fields in line 5194, saw 30
# Skipping line 5215: Expected 25 fields in line 5215, saw 28
# Skipping line 5216: Expected 25 fields in line 5216, saw 28
# Skipping line 10416: Expected 25 fields in line 10416, saw 61
# Skipping line 10799: Expected 25 fields in line 10799, saw 45
# Skipping line 7052: field larger than field limit (131072)
# Skipping line 1526: Expected 25 fields in line 1526, saw 33
# Skipping line 1558: Expected 25 fields in line 1558, saw 33
# Skipping line 1662: Expected 25 fields in line 1662, saw 26
# Skipping line 9922: Expected 25 fields in line 9922, saw 31
# Skipping line 13576: Expected 25 fields in line 13576, saw 26
# Skipping line 31168: Expected 25 fields in line 31168, saw 76
# Skipping line 35812: Expected 25 fields in line 35812, saw 26
# Skipping line 18637: field larger than field limit (131072)
# Skipping line 12199: Expected 25 fields in line 12199, saw 41
# Skipping line 13344: Expected 25 fields in line 13344, saw 37
# Skipping line 14118: Expected 25 fields in line 14118, saw 55
# Skipping line 14119: Expected 25 fields in line 14119, saw 55
# Skipping line 2395: Expected 25 fields in line 2395, saw 38
# Skipping line 3115: Expected 25 fields in line 3115, saw 75
# Skipping line 3116: Expected 25 fields in line 3116, saw 75
# Skipping line 5989: Expected 25 fields in line 5989, saw 44
# Skipping line 13591: Expected 25 fields in line 13591, saw 26
# Skipping line 13592: Expected 25 fields in line 13592, saw 26
# Skipping line 19231: field larger than field limit (131072)
# Skipping line 19243: field larger than field limit (131072)
# Skipping line 19254: field larger than field limit (131072)
# Skipping line 7288: Expected 25 fields in line 7288, saw 28
# Skipping line 9031: Expected 25 fields in line 9031, saw 58
# Skipping line 16890: Expected 25 fields in line 16890, saw 27
# Skipping line 16891: Expected 25 fields in line 16891, saw 27
# Skipping line 16903: Expected 25 fields in line 16903, saw 43
# Skipping line 16904: Expected 25 fields in line 16904, saw 43
# Skipping line 5498: Expected 25 fields in line 5498, saw 52
# Skipping line 5499: Expected 25 fields in line 5499, saw 52
# Skipping line 5353: Expected 25 fields in line 5353, saw 28
# Skipping line 5360: Expected 25 fields in line 5360, saw 27
# Skipping line 5361: Expected 25 fields in line 5361, saw 27
# Skipping line 5362: Expected 25 fields in line 5362, saw 27
# Skipping line 7341: Expected 25 fields in line 7341, saw 48
# Skipping line 7344: Expected 25 fields in line 7344, saw 58
# Skipping line 7346: Expected 25 fields in line 7346, saw 71
# Skipping line 7348: Expected 25 fields in line 7348, saw 73
# Skipping line 7350: Expected 25 fields in line 7350, saw 49
# Skipping line 7359: Expected 25 fields in line 7359, saw 45
# Skipping line 7381: Expected 25 fields in line 7381, saw 65
# Skipping line 7388: Expected 25 fields in line 7388, saw 71
# Skipping line 7409: Expected 25 fields in line 7409, saw 60
# Skipping line 7413: Expected 25 fields in line 7413, saw 57
# Skipping line 7441: Expected 25 fields in line 7441, saw 78
# Skipping line 14318: Expected 25 fields in line 14318, saw 89
# Skipping line 15513: Expected 25 fields in line 15513, saw 132
# Skipping line 15514: Expected 25 fields in line 15514, saw 132
# Skipping line 15537: Expected 25 fields in line 15537, saw 215
# Skipping line 15551: Expected 25 fields in line 15551, saw 181
# Skipping line 15753: Expected 25 fields in line 15753, saw 169
# Skipping line 15754: Expected 25 fields in line 15754, saw 169
# Skipping line 2768: Expected 25 fields in line 2768, saw 46
# Skipping line 2769: Expected 25 fields in line 2769, saw 46
# Skipping line 18824: Expected 25 fields in line 18824, saw 41
# Skipping line 18825: Expected 25 fields in line 18825, saw 41
# Skipping line 5643: Expected 25 fields in line 5643, saw 57
# Skipping line 15402: Expected 25 fields in line 15402, saw 33
# Skipping line 4916: Expected 25 fields in line 4916, saw 27
# Skipping line 4917: Expected 25 fields in line 4917, saw 27
# Skipping line 11641: Expected 25 fields in line 11641, saw 37
# Skipping line 11705: Expected 25 fields in line 11705, saw 37
# Skipping line 11713: Expected 25 fields in line 11713, saw 37
# Skipping line 11788: Expected 25 fields in line 11788, saw 37
# Skipping line 11823: Expected 25 fields in line 11823, saw 37
# Skipping line 14872: Expected 25 fields in line 14872, saw 90
# Skipping line 14888: Expected 25 fields in line 14888, saw 29
# Skipping line 16541: Expected 25 fields in line 16541, saw 42
# Skipping line 16542: Expected 25 fields in line 16542, saw 42
# Skipping line 16543: Expected 25 fields in line 16543, saw 42
# Skipping line 16554: Expected 25 fields in line 16554, saw 42
# Skipping line 16600: Expected 25 fields in line 16600, saw 42
# Skipping line 16616: Expected 25 fields in line 16616, saw 42
# Skipping line 16907: Expected 25 fields in line 16907, saw 26
# Skipping line 16908: Expected 25 fields in line 16908, saw 26
# Skipping line 16909: Expected 25 fields in line 16909, saw 26
# Skipping line 1048: Expected 25 fields in line 1048, saw 35
# Skipping line 1049: Expected 25 fields in line 1049, saw 35
# Skipping line 4962: Expected 25 fields in line 4962, saw 26
# Skipping line 10313: Expected 25 fields in line 10313, saw 61
# Skipping line 14050: Expected 25 fields in line 14050, saw 92
# Skipping line 18824: Expected 25 fields in line 18824, saw 29
# Skipping line 2129: Expected 25 fields in line 2129, saw 26
# Skipping line 6596: Expected 25 fields in line 6596, saw 91
# Skipping line 6601: Expected 25 fields in line 6601, saw 91
# Skipping line 5122: Expected 25 fields in line 5122, saw 164
# Skipping line 5124: Expected 25 fields in line 5124, saw 164
# Skipping line 5248: Expected 25 fields in line 5248, saw 43
# Skipping line 5249: Expected 25 fields in line 5249, saw 43
# Skipping line 13627: Expected 25 fields in line 13627, saw 158
# Skipping line 13628: Expected 25 fields in line 13628, saw 158
# Skipping line 2749: Expected 25 fields in line 2749, saw 64
# Skipping line 3572: Expected 25 fields in line 3572, saw 29
# Skipping line 20443: Expected 25 fields in line 20443, saw 29
# Skipping line 14138: field larger than field limit (131072)
# Skipping line 14139: field larger than field limit (131072)
# Skipping line 14140: field larger than field limit (131072)
# Skipping line 6381: Expected 25 fields in line 6381, saw 50
# Skipping line 7248: Expected 25 fields in line 7248, saw 66
# Skipping line 7846: Expected 25 fields in line 7846, saw 34
# Skipping line 20314: Expected 25 fields in line 20314, saw 52
# Skipping line 20449: Expected 25 fields in line 20449, saw 52
# Skipping line 21161: Expected 25 fields in line 21161, saw 52
# Skipping line 4146: field larger than field limit (131072)
# Skipping line 2993: Expected 25 fields in line 2993, saw 85
# Skipping line 2994: Expected 25 fields in line 2994, saw 85
# Skipping line 7648: Expected 25 fields in line 7648, saw 71
# Skipping line 7649: Expected 25 fields in line 7649, saw 71
# Skipping line 7650: Expected 25 fields in line 7650, saw 71
# Skipping line 13102: Expected 25 fields in line 13102, saw 100
# Skipping line 13104: Expected 25 fields in line 13104, saw 100
# Skipping line 13229: Expected 25 fields in line 13229, saw 46
# Skipping line 4711: field larger than field limit (131072)
# Skipping line 7866: Expected 25 fields in line 7866, saw 26
# Skipping line 16451: field larger than field limit (131072)
# Skipping line 16452: field larger than field limit (131072)
# Skipping line 8868: field larger than field limit (131072)
# Skipping line 8869: field larger than field limit (131072)
# Skipping line 13954: Expected 25 fields in line 13954, saw 28
# Skipping line 13955: Expected 25 fields in line 13955, saw 28
# Skipping line 13956: Expected 25 fields in line 13956, saw 28
# Skipping line 1731: field larger than field limit (131072)
# Skipping line 2053: Expected 25 fields in line 2053, saw 30
# Skipping line 2152: Expected 25 fields in line 2152, saw 30
# Skipping line 7483: Expected 25 fields in line 7483, saw 45
# Skipping line 8867: Expected 25 fields in line 8867, saw 57
# Skipping line 15116: Expected 25 fields in line 15116, saw 26
# Skipping line 15117: Expected 25 fields in line 15117, saw 26
# Skipping line 16756: Expected 25 fields in line 16756, saw 81
# Skipping line 19802: Expected 25 fields in line 19802, saw 193
# Skipping line 5212: Expected 25 fields in line 5212, saw 26
# Skipping line 10645: Expected 25 fields in line 10645, saw 106
# Skipping line 18632: Expected 25 fields in line 18632, saw 45
# Skipping line 21258: Expected 25 fields in line 21258, saw 32
# Skipping line 21259: Expected 25 fields in line 21259, saw 32
# Skipping line 22733: Expected 25 fields in line 22733, saw 60
# Skipping line 15270: Expected 25 fields in line 15270, saw 48
# Skipping line 15273: Expected 25 fields in line 15273, saw 48
# Skipping line 16989: Expected 25 fields in line 16989, saw 27
# Skipping line 17035: Expected 25 fields in line 17035, saw 59
# Skipping line 17040: Expected 25 fields in line 17040, saw 44
# Skipping line 3191: Expected 25 fields in line 3191, saw 57
# Skipping line 3192: Expected 25 fields in line 3192, saw 57
# Skipping line 3205: Expected 25 fields in line 3205, saw 57
# Skipping line 11537: Expected 25 fields in line 11537, saw 28
# Skipping line 3404: field larger than field limit (131072)
# Skipping line 2048: Expected 25 fields in line 2048, saw 43
# Skipping line 4495: Expected 25 fields in line 4495, saw 281
# Skipping line 9734: Expected 25 fields in line 9734, saw 28
# Skipping line 9735: Expected 25 fields in line 9735, saw 28
# Skipping line 3971: Expected 25 fields in line 3971, saw 28
# Skipping line 8075: Expected 25 fields in line 8075, saw 45
# Skipping line 8082: Expected 25 fields in line 8082, saw 45
# Skipping line 8397: Expected 25 fields in line 8397, saw 36
# Skipping line 9190: Expected 25 fields in line 9190, saw 26
# Skipping line 9206: Expected 25 fields in line 9206, saw 26
# Skipping line 9361: Expected 25 fields in line 9361, saw 42
# Skipping line 14060: Expected 25 fields in line 14060, saw 61
# Skipping line 14239: Expected 25 fields in line 14239, saw 67
# Skipping line 14248: Expected 25 fields in line 14248, saw 61
# Skipping line 6793: Expected 25 fields in line 6793, saw 42
# Skipping line 7902: Expected 25 fields in line 7902, saw 43
# Skipping line 7903: Expected 25 fields in line 7903, saw 43
# Skipping line 8010: Expected 25 fields in line 8010, saw 43
# Skipping line 8011: Expected 25 fields in line 8011, saw 43
# Skipping line 11533: Expected 25 fields in line 11533, saw 42
# Skipping line 11536: Expected 25 fields in line 11536, saw 42
# Skipping line 20926: Expected 25 fields in line 20926, saw 38
# Skipping line 24749: Expected 25 fields in line 24749, saw 84
# Skipping line 14414: Expected 25 fields in line 14414, saw 34
# Skipping line 16578: Expected 25 fields in line 16578, saw 70
# Skipping line 16579: Expected 25 fields in line 16579, saw 70
# Skipping line 1492: Expected 25 fields in line 1492, saw 26
# Skipping line 1493: Expected 25 fields in line 1493, saw 26
# Skipping line 3527: Expected 25 fields in line 3527, saw 26
# Skipping line 3528: Expected 25 fields in line 3528, saw 26
# Skipping line 4394: Expected 25 fields in line 4394, saw 67
# Skipping line 4395: Expected 25 fields in line 4395, saw 80
# Skipping line 4397: Expected 25 fields in line 4397, saw 67
# Skipping line 5204: Expected 25 fields in line 5204, saw 26
# Skipping line 5210: Expected 25 fields in line 5210, saw 26
# Skipping line 5274: Expected 25 fields in line 5274, saw 26
# Skipping line 7253: Expected 25 fields in line 7253, saw 35
# Skipping line 10583: Expected 25 fields in line 10583, saw 107
# Skipping line 10585: Expected 25 fields in line 10585, saw 185
# Skipping line 10606: Expected 25 fields in line 10606, saw 107
# Skipping line 10608: Expected 25 fields in line 10608, saw 185
# Skipping line 11895: Expected 25 fields in line 11895, saw 26
# Skipping line 12008: Expected 25 fields in line 12008, saw 27
# Skipping line 8009: Expected 25 fields in line 8009, saw 46
# Skipping line 9238: Expected 25 fields in line 9238, saw 31
# Skipping line 2613: Expected 25 fields in line 2613, saw 57
# Skipping line 2615: Expected 25 fields in line 2615, saw 57
# Skipping line 3657: Expected 25 fields in line 3657, saw 27
# Skipping line 3664: Expected 25 fields in line 3664, saw 28
# Skipping line 3670: Expected 25 fields in line 3670, saw 27
# Skipping line 3714: Expected 25 fields in line 3714, saw 28
# Skipping line 10118: Expected 25 fields in line 10118, saw 100
# Skipping line 10131: Expected 25 fields in line 10131, saw 100
# Skipping line 10132: Expected 25 fields in line 10132, saw 100
# Skipping line 10236: Expected 25 fields in line 10236, saw 100
# Skipping line 17818: Expected 25 fields in line 17818, saw 28
# Skipping line 17819: Expected 25 fields in line 17819, saw 28
# Skipping line 16222: field larger than field limit (131072)
# Skipping line 16223: field larger than field limit (131072)
# Skipping line 7882: Expected 25 fields in line 7882, saw 45
# Skipping line 16305: Expected 25 fields in line 16305, saw 301
# Skipping line 16306: Expected 25 fields in line 16306, saw 301
# Skipping line 9117: Expected 25 fields in line 9117, saw 26
# Skipping line 5298: Expected 25 fields in line 5298, saw 59
# Skipping line 5299: Expected 25 fields in line 5299, saw 59
# Skipping line 6290: Expected 25 fields in line 6290, saw 27
# Skipping line 6291: Expected 25 fields in line 6291, saw 27
# Skipping line 4648: Expected 25 fields in line 4648, saw 56
# Skipping line 4649: Expected 25 fields in line 4649, saw 56
# Skipping line 2960: Expected 25 fields in line 2960, saw 28
# Skipping line 4083: Expected 25 fields in line 4083, saw 51
# Skipping line 5639: Expected 25 fields in line 5639, saw 26
# Skipping line 11051: Expected 25 fields in line 11051, saw 30
# Skipping line 11417: Expected 25 fields in line 11417, saw 26
# Skipping line 5210: Expected 25 fields in line 5210, saw 26
# Skipping line 5211: Expected 25 fields in line 5211, saw 26
# Skipping line 9891: Expected 25 fields in line 9891, saw 36
# Skipping line 9892: Expected 25 fields in line 9892, saw 36
# Skipping line 9937: Expected 25 fields in line 9937, saw 31
# Skipping line 9938: Expected 25 fields in line 9938, saw 31
# Skipping line 13057: Expected 25 fields in line 13057, saw 27
# Skipping line 13058: Expected 25 fields in line 13058, saw 27
# Skipping line 6168: Expected 25 fields in line 6168, saw 38
# Skipping line 6169: Expected 25 fields in line 6169, saw 38
# Skipping line 3785: Expected 25 fields in line 3785, saw 60
# Skipping line 3789: Expected 25 fields in line 3789, saw 60
# Skipping line 3792: Expected 25 fields in line 3792, saw 60
# Skipping line 14798: Expected 25 fields in line 14798, saw 26
# Skipping line 24271: Expected 25 fields in line 24271, saw 30
# Skipping line 24276: Expected 25 fields in line 24276, saw 69
# Skipping line 24319: Expected 25 fields in line 24319, saw 31
# Skipping line 24323: Expected 25 fields in line 24323, saw 28
# Skipping line 3058: Expected 25 fields in line 3058, saw 35
# Skipping line 3059: Expected 25 fields in line 3059, saw 35
# Skipping line 14535: Expected 25 fields in line 14535, saw 29
# Skipping line 14544: Expected 25 fields in line 14544, saw 29
# Skipping line 8409: Expected 25 fields in line 8409, saw 30
# Skipping line 15004: Expected 25 fields in line 15004, saw 26
# Skipping line 15026: Expected 25 fields in line 15026, saw 46
# Skipping line 15027: Expected 25 fields in line 15027, saw 53
# Skipping line 15028: Expected 25 fields in line 15028, saw 26
# Skipping line 15030: Expected 25 fields in line 15030, saw 46
# Skipping line 4222: Expected 25 fields in line 4222, saw 26
# Skipping line 4625: Expected 25 fields in line 4625, saw 203
# Skipping line 4626: Expected 25 fields in line 4626, saw 203
# Skipping line 6807: Expected 25 fields in line 6807, saw 30
# Skipping line 10425: Expected 25 fields in line 10425, saw 36
# Skipping line 10429: Expected 25 fields in line 10429, saw 36
# Skipping line 10457: Expected 25 fields in line 10457, saw 36
# Skipping line 6307: Expected 25 fields in line 6307, saw 26
# Skipping line 1561: Expected 25 fields in line 1561, saw 28
# Skipping line 1572: Expected 25 fields in line 1572, saw 28
# Skipping line 4075: Expected 25 fields in line 4075, saw 39
# Skipping line 5179: Expected 25 fields in line 5179, saw 68
# Skipping line 6448: Expected 25 fields in line 6448, saw 39
# Skipping line 6449: Expected 25 fields in line 6449, saw 39
# Skipping line 7648: Expected 25 fields in line 7648, saw 65
# Skipping line 9066: Expected 25 fields in line 9066, saw 28
# Skipping line 4381: Expected 25 fields in line 4381, saw 33
# Skipping line 4382: Expected 25 fields in line 4382, saw 33
# Skipping line 8392: Expected 25 fields in line 8392, saw 57
# Skipping line 12142: Expected 25 fields in line 12142, saw 28
# Skipping line 15879: Expected 25 fields in line 15879, saw 27
# Skipping line 2009: Expected 25 fields in line 2009, saw 26
# Skipping line 2010: Expected 25 fields in line 2010, saw 26
# Skipping line 2014: Expected 25 fields in line 2014, saw 26
# Skipping line 2556: Expected 25 fields in line 2556, saw 26
# Skipping line 7901: Expected 25 fields in line 7901, saw 31
# Skipping line 7956: Expected 25 fields in line 7956, saw 69
# Skipping line 9223: Expected 25 fields in line 9223, saw 55
# Skipping line 12607: field larger than field limit (131072)
# Skipping line 17913: Expected 25 fields in line 17913, saw 65
# Skipping line 17914: Expected 25 fields in line 17914, saw 65
# Skipping line 3225: Expected 25 fields in line 3225, saw 26
# Skipping line 3226: Expected 25 fields in line 3226, saw 26
# Skipping line 3227: Expected 25 fields in line 3227, saw 26
# Skipping line 18804: Expected 25 fields in line 18804, saw 49
# Skipping line 18805: Expected 25 fields in line 18805, saw 49
# Skipping line 19656: Expected 25 fields in line 19656, saw 132
# Skipping line 4763: field larger than field limit (131072)
# Skipping line 1876: Expected 25 fields in line 1876, saw 49
# Skipping line 4891: Expected 25 fields in line 4891, saw 54
# Skipping line 4893: Expected 25 fields in line 4893, saw 54
# Skipping line 4895: Expected 25 fields in line 4895, saw 54
# Skipping line 6275: Expected 25 fields in line 6275, saw 92
# Skipping line 6276: Expected 25 fields in line 6276, saw 92
# Skipping line 10337: Expected 25 fields in line 10337, saw 66
# Skipping line 11612: Expected 25 fields in line 11612, saw 32
# Skipping line 1093: Expected 25 fields in line 1093, saw 27
# Skipping line 1182: Expected 25 fields in line 1182, saw 27
# Skipping line 2018: Expected 25 fields in line 2018, saw 42
# Skipping line 6241: Expected 25 fields in line 6241, saw 85
# Skipping line 6242: Expected 25 fields in line 6242, saw 85
# Skipping line 12392: Expected 25 fields in line 12392, saw 26
# Skipping line 12393: Expected 25 fields in line 12393, saw 26
# Skipping line 15763: Expected 25 fields in line 15763, saw 27
# Skipping line 15764: Expected 25 fields in line 15764, saw 27
# Skipping line 15765: Expected 25 fields in line 15765, saw 27
# Skipping line 15813: Expected 25 fields in line 15813, saw 28
# Skipping line 15834: Expected 25 fields in line 15834, saw 28
# Skipping line 15870: Expected 25 fields in line 15870, saw 27
# Skipping line 16720: Expected 25 fields in line 16720, saw 34
# Skipping line 16721: Expected 25 fields in line 16721, saw 26
# Skipping line 16768: Expected 25 fields in line 16768, saw 26
# Skipping line 16770: Expected 25 fields in line 16770, saw 28
# Skipping line 16877: Expected 25 fields in line 16877, saw 54
# Skipping line 16882: Expected 25 fields in line 16882, saw 70
# Skipping line 22798: Expected 25 fields in line 22798, saw 140
# Skipping line 22799: Expected 25 fields in line 22799, saw 140
# Skipping line 22800: Expected 25 fields in line 22800, saw 140
# Skipping line 3459: Expected 25 fields in line 3459, saw 209
# Skipping line 3460: Expected 25 fields in line 3460, saw 209
# Skipping line 3462: Expected 25 fields in line 3462, saw 209
# Skipping line 16358: Expected 25 fields in line 16358, saw 26
# Skipping line 16365: Expected 25 fields in line 16365, saw 26
# Skipping line 1432: Expected 25 fields in line 1432, saw 91
# Skipping line 6128: Expected 25 fields in line 6128, saw 26
# Skipping line 6129: Expected 25 fields in line 6129, saw 26
# Skipping line 6164: Expected 25 fields in line 6164, saw 26
# Skipping line 6165: Expected 25 fields in line 6165, saw 26
# Skipping line 10541: Expected 25 fields in line 10541, saw 38
# Skipping line 2808: Expected 25 fields in line 2808, saw 209
# Skipping line 2809: Expected 25 fields in line 2809, saw 209
# Skipping line 5728: Expected 25 fields in line 5728, saw 46
# Skipping line 6578: Expected 25 fields in line 6578, saw 46
# Skipping line 8496: Expected 25 fields in line 8496, saw 53
# Skipping line 8497: Expected 25 fields in line 8497, saw 53
# Skipping line 3429: Expected 25 fields in line 3429, saw 27
# Skipping line 7840: Expected 25 fields in line 7840, saw 59
# Skipping line 7843: Expected 25 fields in line 7843, saw 59
# Skipping line 9636: Expected 25 fields in line 9636, saw 37
# Skipping line 11160: Expected 25 fields in line 11160, saw 55
# Skipping line 14108: Expected 25 fields in line 14108, saw 44
# Skipping line 14128: Expected 25 fields in line 14128, saw 42
# Skipping line 14131: Expected 25 fields in line 14131, saw 57
# Skipping line 14136: Expected 25 fields in line 14136, saw 43
# Skipping line 9308: Expected 25 fields in line 9308, saw 75
# Skipping line 9735: Expected 25 fields in line 9735, saw 40
# Skipping line 9763: Expected 25 fields in line 9763, saw 259
# Skipping line 9764: Expected 25 fields in line 9764, saw 35
# Skipping line 9765: Expected 25 fields in line 9765, saw 35
# Skipping line 10283: Expected 25 fields in line 10283, saw 29
# Skipping line 10284: Expected 25 fields in line 10284, saw 29
# Skipping line 14475: Expected 25 fields in line 14475, saw 30
# Skipping line 14476: Expected 25 fields in line 14476, saw 30
# Skipping line 17395: field larger than field limit (131072)
# Skipping line 16208: Expected 25 fields in line 16208, saw 56
# Skipping line 16254: Expected 25 fields in line 16254, saw 46
# Skipping line 16258: Expected 25 fields in line 16258, saw 46
# Skipping line 17403: Expected 25 fields in line 17403, saw 73
# Skipping line 17410: Expected 25 fields in line 17410, saw 73
# Skipping line 8595: Expected 25 fields in line 8595, saw 55
# Skipping line 8596: Expected 25 fields in line 8596, saw 55
# Skipping line 8597: Expected 25 fields in line 8597, saw 55
# Skipping line 8607: Expected 25 fields in line 8607, saw 71
# Skipping line 11988: Expected 25 fields in line 11988, saw 32
# Skipping line 12702: Expected 25 fields in line 12702, saw 50
# Skipping line 12733: Expected 25 fields in line 12733, saw 50
# Skipping line 18683: Expected 25 fields in line 18683, saw 27
# Skipping line 18693: Expected 25 fields in line 18693, saw 29
# Skipping line 19513: Expected 25 fields in line 19513, saw 78
# Skipping line 19520: Expected 25 fields in line 19520, saw 29
# Skipping line 19524: Expected 25 fields in line 19524, saw 42
# Skipping line 19526: Expected 25 fields in line 19526, saw 29
# Skipping line 19664: Expected 25 fields in line 19664, saw 70
# Skipping line 19667: Expected 25 fields in line 19667, saw 54
# Skipping line 19669: Expected 25 fields in line 19669, saw 49
# Skipping line 19676: Expected 25 fields in line 19676, saw 43
# Skipping line 19680: Expected 25 fields in line 19680, saw 44
# Skipping line 4344: Expected 25 fields in line 4344, saw 28
# Skipping line 4354: Expected 25 fields in line 4354, saw 28
# Skipping line 6114: Expected 25 fields in line 6114, saw 27
# Skipping line 6472: Expected 25 fields in line 6472, saw 27
# Skipping line 7135: Expected 25 fields in line 7135, saw 58
# Skipping line 7136: Expected 25 fields in line 7136, saw 58
# Skipping line 7137: Expected 25 fields in line 7137, saw 58
# Skipping line 7798: Expected 25 fields in line 7798, saw 40
# Skipping line 6977: Expected 25 fields in line 6977, saw 49
# Skipping line 9986: Expected 25 fields in line 9986, saw 49
# Skipping line 9988: Expected 25 fields in line 9988, saw 43
# Skipping line 9989: Expected 25 fields in line 9989, saw 43
# Skipping line 9991: Expected 25 fields in line 9991, saw 34
# Skipping line 9993: Expected 25 fields in line 9993, saw 31
# Skipping line 9996: Expected 25 fields in line 9996, saw 32
# Skipping line 10011: Expected 25 fields in line 10011, saw 58
# Skipping line 10015: Expected 25 fields in line 10015, saw 75
# Skipping line 10019: Expected 25 fields in line 10019, saw 51
# Skipping line 13412: Expected 25 fields in line 13412, saw 42
# Skipping line 13413: Expected 25 fields in line 13413, saw 42
# Skipping line 16323: Expected 25 fields in line 16323, saw 26
# Skipping line 23393: Expected 25 fields in line 23393, saw 60
# Skipping line 29222: Expected 25 fields in line 29222, saw 60
# Skipping line 29263: Expected 25 fields in line 29263, saw 55
# Skipping line 6320: Expected 25 fields in line 6320, saw 70
# Skipping line 11003: Expected 25 fields in line 11003, saw 31
# Skipping line 11004: Expected 25 fields in line 11004, saw 31
# Skipping line 11007: Expected 25 fields in line 11007, saw 31
# Skipping line 9350: Expected 25 fields in line 9350, saw 29
# Skipping line 9363: Expected 25 fields in line 9363, saw 26
# Skipping line 3929: Expected 25 fields in line 3929, saw 26
# Skipping line 3930: Expected 25 fields in line 3930, saw 26
# Skipping line 6880: Expected 25 fields in line 6880, saw 26
# Skipping line 6936: Expected 25 fields in line 6936, saw 28
# Skipping line 10305: Expected 25 fields in line 10305, saw 56
# Skipping line 30: field larger than field limit (131072)
# Skipping line 31: field larger than field limit (131072)
# Skipping line 59: field larger than field limit (131072)
# Skipping line 60: field larger than field limit (131072)
# Skipping line 66: field larger than field limit (131072)
# Skipping line 67: field larger than field limit (131072)
# Skipping line 18811: Expected 25 fields in line 18811, saw 28
# Skipping line 18812: Expected 25 fields in line 18812, saw 28
# Skipping line 2055: Expected 25 fields in line 2055, saw 45
# Skipping line 2056: Expected 25 fields in line 2056, saw 45
# Skipping line 2504: Expected 25 fields in line 2504, saw 69
# Skipping line 2505: Expected 25 fields in line 2505, saw 69
# Skipping line 2552: Expected 25 fields in line 2552, saw 38
# Skipping line 2858: Expected 25 fields in line 2858, saw 120
# Skipping line 2859: Expected 25 fields in line 2859, saw 120
# Skipping line 15822: field larger than field limit (131072)
# Skipping line 7847: Expected 25 fields in line 7847, saw 71
# Skipping line 11414: Expected 25 fields in line 11414, saw 27
# Skipping line 9472: Expected 25 fields in line 9472, saw 26
# Skipping line 12988: Expected 25 fields in line 12988, saw 30
# Skipping line 12989: Expected 25 fields in line 12989, saw 30
# Skipping line 2555: Expected 25 fields in line 2555, saw 89
# Skipping line 2556: Expected 25 fields in line 2556, saw 89
# Skipping line 2557: Expected 25 fields in line 2557, saw 89
# Skipping line 2560: Expected 25 fields in line 2560, saw 82
# Skipping line 2575: Expected 25 fields in line 2575, saw 113
# Skipping line 4107: Expected 25 fields in line 4107, saw 49
# Skipping line 12901: Expected 25 fields in line 12901, saw 41
# Skipping line 12915: Expected 25 fields in line 12915, saw 41
# Skipping line 12916: Expected 25 fields in line 12916, saw 41
# Skipping line 12641: Expected 25 fields in line 12641, saw 102
# Skipping line 12713: Expected 25 fields in line 12713, saw 27
# Skipping line 12714: Expected 25 fields in line 12714, saw 27
# Skipping line 12715: Expected 25 fields in line 12715, saw 27
# Skipping line 13951: Expected 25 fields in line 13951, saw 118
# Skipping line 13952: Expected 25 fields in line 13952, saw 118
# Skipping line 7618: Expected 25 fields in line 7618, saw 49
# Skipping line 13085: Expected 25 fields in line 13085, saw 29
# Skipping line 13086: Expected 25 fields in line 13086, saw 29
# Skipping line 13102: Expected 25 fields in line 13102, saw 29
# Skipping line 13103: Expected 25 fields in line 13103, saw 29
# Skipping line 13618: Expected 25 fields in line 13618, saw 38
# Skipping line 13652: Expected 25 fields in line 13652, saw 33
# Skipping line 14932: Expected 25 fields in line 14932, saw 42
# Skipping line 17043: Expected 25 fields in line 17043, saw 61
# Skipping line 4606: field larger than field limit (131072)
# Skipping line 6274: Expected 25 fields in line 6274, saw 26
# Skipping line 6419: Expected 25 fields in line 6419, saw 26
# Skipping line 12764: Expected 25 fields in line 12764, saw 112
# Skipping line 2235: Expected 25 fields in line 2235, saw 78
# Skipping line 4218: Expected 25 fields in line 4218, saw 46
# Skipping line 6223: Expected 25 fields in line 6223, saw 68
# Skipping line 7027: Expected 25 fields in line 7027, saw 31
# Skipping line 7028: Expected 25 fields in line 7028, saw 31
# Skipping line 7108: Expected 25 fields in line 7108, saw 31
# Skipping line 7456: Expected 25 fields in line 7456, saw 41
# Skipping line 7457: Expected 25 fields in line 7457, saw 41
# Skipping line 9876: Expected 25 fields in line 9876, saw 184
# Skipping line 9877: Expected 25 fields in line 9877, saw 184
# Skipping line 9878: Expected 25 fields in line 9878, saw 184
# Skipping line 10107: Expected 25 fields in line 10107, saw 183
# Skipping line 4986: Expected 25 fields in line 4986, saw 46
# Skipping line 5438: Expected 25 fields in line 5438, saw 38
# Skipping line 8884: Expected 25 fields in line 8884, saw 124
# Skipping line 8890: Expected 25 fields in line 8890, saw 124
# Skipping line 8895: Expected 25 fields in line 8895, saw 124
# Skipping line 16997: Expected 25 fields in line 16997, saw 26
# Skipping line 16998: Expected 25 fields in line 16998, saw 26
# Skipping line 2790: Expected 25 fields in line 2790, saw 48
# Skipping line 2791: Expected 25 fields in line 2791, saw 48
# Skipping line 8559: Expected 25 fields in line 8559, saw 49
# Skipping line 9917: Expected 25 fields in line 9917, saw 28
# Skipping line 9918: Expected 25 fields in line 9918, saw 28
# Skipping line 9919: Expected 25 fields in line 9919, saw 28
# Skipping line 3570: Expected 25 fields in line 3570, saw 84
# Skipping line 14690: field larger than field limit (131072)
# Skipping line 14718: Expected 25 fields in line 14718, saw 73
# Skipping line 14719: Expected 25 fields in line 14719, saw 73
# Skipping line 14720: Expected 25 fields in line 14720, saw 73
# Skipping line 18049: Expected 25 fields in line 18049, saw 27
# Skipping line 18050: Expected 25 fields in line 18050, saw 27
# Skipping line 18051: Expected 25 fields in line 18051, saw 27
# Skipping line 18080: Expected 25 fields in line 18080, saw 27
# Skipping line 18655: Expected 25 fields in line 18655, saw 97
# Skipping line 18656: Expected 25 fields in line 18656, saw 97
# Skipping line 3031: field larger than field limit (131072)
# Skipping line 3032: field larger than field limit (131072)
# Skipping line 2011: Expected 25 fields in line 2011, saw 57
# Skipping line 6773: Expected 25 fields in line 6773, saw 28
# Skipping line 6774: Expected 25 fields in line 6774, saw 28
# Skipping line 12211: Expected 25 fields in line 12211, saw 26
# Skipping line 15691: Expected 25 fields in line 15691, saw 30
# Skipping line 11199: Expected 25 fields in line 11199, saw 34
# Skipping line 11202: Expected 25 fields in line 11202, saw 29
# Skipping line 2993: Expected 25 fields in line 2993, saw 93
# Skipping line 14751: Expected 25 fields in line 14751, saw 46
# Skipping line 61: field larger than field limit (131072)
# Skipping line 64: field larger than field limit (131072)
# Skipping line 13535: Expected 25 fields in line 13535, saw 66
# Skipping line 8515: Expected 25 fields in line 8515, saw 100
# Skipping line 8516: Expected 25 fields in line 8516, saw 100
# Skipping line 8549: Expected 25 fields in line 8549, saw 45
# Skipping line 9942: Expected 25 fields in line 9942, saw 43
# Skipping line 9944: Expected 25 fields in line 9944, saw 55
# Skipping line 12341: Expected 25 fields in line 12341, saw 58
# Skipping line 12509: Expected 25 fields in line 12509, saw 58
# Skipping line 12677: Expected 25 fields in line 12677, saw 58
# Skipping line 2553: Expected 25 fields in line 2553, saw 27
# Skipping line 2744: Expected 25 fields in line 2744, saw 28
# Skipping line 6037: Expected 25 fields in line 6037, saw 64
# Skipping line 6610: Expected 25 fields in line 6610, saw 46
# Skipping line 6650: Expected 25 fields in line 6650, saw 46
# Skipping line 7656: Expected 25 fields in line 7656, saw 27
# Skipping line 13458: Expected 25 fields in line 13458, saw 96
# Skipping line 13459: Expected 25 fields in line 13459, saw 96
# Skipping line 21111: Expected 25 fields in line 21111, saw 44
# Skipping line 21114: Expected 25 fields in line 21114, saw 44
# Skipping line 3219: Expected 25 fields in line 3219, saw 274
# Skipping line 13601: Expected 25 fields in line 13601, saw 36
# Skipping line 14697: Expected 25 fields in line 14697, saw 44
# Skipping line 14698: Expected 25 fields in line 14698, saw 44
# Skipping line 4523: Expected 25 fields in line 4523, saw 26
# Skipping line 4524: Expected 25 fields in line 4524, saw 26
# Skipping line 6068: Expected 25 fields in line 6068, saw 61
# Skipping line 21560: Expected 25 fields in line 21560, saw 61
# Skipping line 21561: Expected 25 fields in line 21561, saw 61
# Skipping line 24828: Expected 25 fields in line 24828, saw 203
# Skipping line 24927: Expected 25 fields in line 24927, saw 75
# Skipping line 25909: Expected 25 fields in line 25909, saw 35
# Skipping line 4210: Expected 25 fields in line 4210, saw 26
# Skipping line 4237: Expected 25 fields in line 4237, saw 26
# Skipping line 7598: Expected 25 fields in line 7598, saw 76
# Skipping line 1308: field larger than field limit (131072)
# Skipping line 5202: Expected 25 fields in line 5202, saw 245
# Skipping line 5788: Expected 25 fields in line 5788, saw 75
# Skipping line 5801: Expected 25 fields in line 5801, saw 75
# Skipping line 8906: Expected 25 fields in line 8906, saw 39
# Skipping line 13056: Expected 25 fields in line 13056, saw 36
# Skipping line 13094: Expected 25 fields in line 13094, saw 36
# Skipping line 13096: Expected 25 fields in line 13096, saw 36
# Skipping line 8372: field larger than field limit (131072)
# Skipping line 7970: Expected 25 fields in line 7970, saw 74
# Skipping line 15417: Expected 25 fields in line 15417, saw 53
# Skipping line 15689: Expected 25 fields in line 15689, saw 59
# Skipping line 2017: Expected 25 fields in line 2017, saw 26
# Skipping line 2421: Expected 25 fields in line 2421, saw 107
# Skipping line 2423: Expected 25 fields in line 2423, saw 185
# Skipping line 2443: Expected 25 fields in line 2443, saw 107
# Skipping line 2445: Expected 25 fields in line 2445, saw 185
# Skipping line 2473: Expected 25 fields in line 2473, saw 27
# Skipping line 8100: Expected 25 fields in line 8100, saw 34
# Skipping line 8310: Expected 25 fields in line 8310, saw 47
# Skipping line 9742: Expected 25 fields in line 9742, saw 26
# Skipping line 13322: Expected 25 fields in line 13322, saw 65
# Skipping line 15095: Expected 25 fields in line 15095, saw 66
# Skipping line 27152: Expected 25 fields in line 27152, saw 27
# Skipping line 5384: Expected 25 fields in line 5384, saw 27
# Skipping line 5388: Expected 25 fields in line 5388, saw 27
# Skipping line 5389: Expected 25 fields in line 5389, saw 27
# Skipping line 5391: Expected 25 fields in line 5391, saw 27
# Skipping line 5403: Expected 25 fields in line 5403, saw 27
# Skipping line 3521: Expected 25 fields in line 3521, saw 42
# Skipping line 3704: Expected 25 fields in line 3704, saw 42
# Skipping line 9903: Expected 25 fields in line 9903, saw 26
# Skipping line 9904: Expected 25 fields in line 9904, saw 26
# Skipping line 10014: Expected 25 fields in line 10014, saw 26
# Skipping line 11346: Expected 25 fields in line 11346, saw 76
# Skipping line 11349: Expected 25 fields in line 11349, saw 76
# Skipping line 11352: Expected 25 fields in line 11352, saw 76
# Skipping line 11478: Expected 25 fields in line 11478, saw 65
# Skipping line 11483: Expected 25 fields in line 11483, saw 65
# Skipping line 13476: Expected 25 fields in line 13476, saw 26
# Skipping line 16231: Expected 25 fields in line 16231, saw 42
# Skipping line 20163: Expected 25 fields in line 20163, saw 42
# Skipping line 20624: Expected 25 fields in line 20624, saw 131
# Skipping line 21274: Expected 25 fields in line 21274, saw 37
# Skipping line 21275: Expected 25 fields in line 21275, saw 37
# Skipping line 21461: Expected 25 fields in line 21461, saw 34
# Skipping line 21605: Expected 25 fields in line 21605, saw 37
# Skipping line 7812: Expected 25 fields in line 7812, saw 30
# Skipping line 7819: Expected 25 fields in line 7819, saw 30
# Skipping line 7876: Expected 25 fields in line 7876, saw 99
# Skipping line 7904: Expected 25 fields in line 7904, saw 99
# Skipping line 7926: Expected 25 fields in line 7926, saw 51
# Skipping line 7931: Expected 25 fields in line 7931, saw 148
# Skipping line 7936: Expected 25 fields in line 7936, saw 148
# Skipping line 8724: Expected 25 fields in line 8724, saw 148
# Skipping line 8743: Expected 25 fields in line 8743, saw 148
# Skipping line 8773: Expected 25 fields in line 8773, saw 51
# Skipping line 10772: Expected 25 fields in line 10772, saw 75
# Skipping line 10892: Expected 25 fields in line 10892, saw 37
# Skipping line 10893: Expected 25 fields in line 10893, saw 37
# Skipping line 17782: Expected 25 fields in line 17782, saw 28
# Skipping line 18721: Expected 25 fields in line 18721, saw 28
# Skipping line 20467: Expected 25 fields in line 20467, saw 91
# Skipping line 20468: Expected 25 fields in line 20468, saw 91
# Skipping line 20486: Expected 25 fields in line 20486, saw 51
# Skipping line 3661: Expected 25 fields in line 3661, saw 44
# Skipping line 3663: Expected 25 fields in line 3663, saw 44
# Skipping line 5238: Expected 25 fields in line 5238, saw 80
# Skipping line 5239: Expected 25 fields in line 5239, saw 80
# Skipping line 12595: Expected 25 fields in line 12595, saw 46
# Skipping line 12596: Expected 25 fields in line 12596, saw 63
# Skipping line 12597: Expected 25 fields in line 12597, saw 30
# Skipping line 2798: Expected 25 fields in line 2798, saw 54
# Skipping line 7155: Expected 25 fields in line 7155, saw 38
# Skipping line 10072: Expected 25 fields in line 10072, saw 70
# Skipping line 10075: Expected 25 fields in line 10075, saw 70
# Skipping line 10078: Expected 25 fields in line 10078, saw 70
# Skipping line 10092: Expected 25 fields in line 10092, saw 65
# Skipping line 10095: Expected 25 fields in line 10095, saw 65
# Skipping line 1097: Expected 25 fields in line 1097, saw 33
# Skipping line 1098: Expected 25 fields in line 1098, saw 33
# Skipping line 11731: Expected 25 fields in line 11731, saw 43
# Skipping line 13484: Expected 25 fields in line 13484, saw 30
# Skipping line 17100: Expected 25 fields in line 17100, saw 50
# Skipping line 2731: Expected 25 fields in line 2731, saw 32
# Skipping line 1761: field larger than field limit (131072)
# Skipping line 1762: field larger than field limit (131072)
# Skipping line 1764: field larger than field limit (131072)
# Skipping line 10328: field larger than field limit (131072)
# Skipping line 2822: Expected 25 fields in line 2822, saw 79
# Skipping line 3770: Expected 25 fields in line 3770, saw 58
# Skipping line 15522: Expected 25 fields in line 15522, saw 26
# Skipping line 15529: Expected 25 fields in line 15529, saw 26
# Skipping line 10844: Expected 25 fields in line 10844, saw 30
# Skipping line 11437: Expected 25 fields in line 11437, saw 35
# Skipping line 11481: Expected 25 fields in line 11481, saw 26
# Skipping line 7923: Expected 25 fields in line 7923, saw 120
# Skipping line 7924: Expected 25 fields in line 7924, saw 52
# Skipping line 7942: Expected 25 fields in line 7942, saw 120
# Skipping line 7943: Expected 25 fields in line 7943, saw 52
# Skipping line 9615: Expected 25 fields in line 9615, saw 29
# Skipping line 18144: Expected 25 fields in line 18144, saw 36
# Skipping line 18145: Expected 25 fields in line 18145, saw 36
# Skipping line 1748: Expected 25 fields in line 1748, saw 193
# Skipping line 1749: Expected 25 fields in line 1749, saw 193
# Skipping line 19279: field larger than field limit (131072)
# Skipping line 21085: Expected 25 fields in line 21085, saw 29
# Skipping line 21167: Expected 25 fields in line 21167, saw 31
# Skipping line 4197: field larger than field limit (131072)
# Skipping line 2993: Expected 25 fields in line 2993, saw 30
# Skipping line 2994: Expected 25 fields in line 2994, saw 30
# Skipping line 4155: Expected 25 fields in line 4155, saw 45
# Skipping line 9760: Expected 25 fields in line 9760, saw 28
# Skipping line 9775: Expected 25 fields in line 9775, saw 30
# Skipping line 9802: Expected 25 fields in line 9802, saw 28
# Skipping line 9803: Expected 25 fields in line 9803, saw 30
# Skipping line 1263: Expected 25 fields in line 1263, saw 26
# Skipping line 1264: Expected 25 fields in line 1264, saw 26
# Skipping line 3042: Expected 25 fields in line 3042, saw 26
# Skipping line 3684: Expected 25 fields in line 3684, saw 115
# Skipping line 9895: Expected 25 fields in line 9895, saw 26
# Skipping line 6682: Expected 25 fields in line 6682, saw 26
# Skipping line 6683: Expected 25 fields in line 6683, saw 26
# Skipping line 6684: Expected 25 fields in line 6684, saw 26
# Skipping line 6685: Expected 25 fields in line 6685, saw 26
# Skipping line 6687: Expected 25 fields in line 6687, saw 26
# Skipping line 10192: Expected 25 fields in line 10192, saw 30
# Skipping line 10193: Expected 25 fields in line 10193, saw 30
# Skipping line 19749: Expected 25 fields in line 19749, saw 67
# Skipping line 19750: Expected 25 fields in line 19750, saw 67
# Skipping line 13596: field larger than field limit (131072)
# Skipping line 20007: Expected 25 fields in line 20007, saw 26
# Skipping line 20008: Expected 25 fields in line 20008, saw 26
# Skipping line 3865: field larger than field limit (131072)
# Skipping line 20136: Expected 25 fields in line 20136, saw 52
# Skipping line 20137: Expected 25 fields in line 20137, saw 41
# Skipping line 20140: Expected 25 fields in line 20140, saw 82
# Skipping line 20148: Expected 25 fields in line 20148, saw 30
# Skipping line 20150: Expected 25 fields in line 20150, saw 52
# Skipping line 20151: Expected 25 fields in line 20151, saw 57
# Skipping line 20156: Expected 25 fields in line 20156, saw 31
# Skipping line 20161: Expected 25 fields in line 20161, saw 61
# Skipping line 20166: Expected 25 fields in line 20166, saw 49
# Skipping line 2514: Expected 25 fields in line 2514, saw 26
# Skipping line 18663: Expected 25 fields in line 18663, saw 38
# Skipping line 18665: Expected 25 fields in line 18665, saw 38
# Skipping line 7667: Expected 25 fields in line 7667, saw 54
# Skipping line 7668: Expected 25 fields in line 7668, saw 54
# Skipping line 11328: Expected 25 fields in line 11328, saw 78
# Skipping line 9764: field larger than field limit (131072)
# Skipping line 11250: Expected 25 fields in line 11250, saw 57
# Skipping line 11251: Expected 25 fields in line 11251, saw 57
# Skipping line 11252: Expected 25 fields in line 11252, saw 57
# Skipping line 11712: Expected 25 fields in line 11712, saw 26
# Skipping line 1126: field larger than field limit (131072)
# Skipping line 2747: Expected 25 fields in line 2747, saw 29
# Skipping line 2748: Expected 25 fields in line 2748, saw 29
# Skipping line 3251: Expected 25 fields in line 3251, saw 56
# Skipping line 3252: Expected 25 fields in line 3252, saw 56
# Skipping line 3257: Expected 25 fields in line 3257, saw 78
# Skipping line 3260: Expected 25 fields in line 3260, saw 78
# Skipping line 3263: Expected 25 fields in line 3263, saw 78
# Skipping line 3388: Expected 25 fields in line 3388, saw 78
# Skipping line 3501: Expected 25 fields in line 3501, saw 78
# Skipping line 7922: Expected 25 fields in line 7922, saw 84
# Skipping line 7923: Expected 25 fields in line 7923, saw 84
# Skipping line 10447: Expected 25 fields in line 10447, saw 46
# Skipping line 11626: Expected 25 fields in line 11626, saw 49
# Skipping line 4194: Expected 25 fields in line 4194, saw 28
# Skipping line 6481: Expected 25 fields in line 6481, saw 40
# Skipping line 6482: Expected 25 fields in line 6482, saw 40
# Skipping line 1522: Expected 25 fields in line 1522, saw 59
# Skipping line 1523: Expected 25 fields in line 1523, saw 59
# Skipping line 10013: Expected 25 fields in line 10013, saw 61
# Skipping line 11194: Expected 25 fields in line 11194, saw 61
# Skipping line 12621: Expected 25 fields in line 12621, saw 26
# Skipping line 12622: Expected 25 fields in line 12622, saw 26
# Skipping line 1997: Expected 25 fields in line 1997, saw 26
# Skipping line 1998: Expected 25 fields in line 1998, saw 26
# Skipping line 1999: Expected 25 fields in line 1999, saw 26
# Skipping line 3813: Expected 25 fields in line 3813, saw 33
# Skipping line 5836: Expected 25 fields in line 5836, saw 33
# Skipping line 9100: Expected 25 fields in line 9100, saw 46
# Skipping line 9103: Expected 25 fields in line 9103, saw 46
# Skipping line 4027: Expected 25 fields in line 4027, saw 29
# Skipping line 4028: Expected 25 fields in line 4028, saw 29
# Skipping line 4123: Expected 25 fields in line 4123, saw 29
# Skipping line 4124: Expected 25 fields in line 4124, saw 29
# Skipping line 6606: Expected 25 fields in line 6606, saw 51
# ...
# Skipping line 6121: field larger than field limit (131072)
# Skipping line 2473: Expected 25 fields in line 2473, saw 60
# Skipping line 5194: Expected 25 fields in line 5194, saw 33
# Skipping line 5205: Expected 25 fields in line 5205, saw 48
# Skipping line 5209: Expected 25 fields in line 5209, saw 36
# Skipping line 5215: Expected 25 fields in line 5215, saw 48
# Skipping line 5824: Expected 25 fields in line 5824, saw 27
# Skipping line 11626: Expected 25 fields in line 11626, saw 40
# Skipping line 11627: Expected 25 fields in line 11627, saw 40
# Skipping line 13139: Expected 25 fields in line 13139, saw 61
# Skipping line 2853: Expected 25 fields in line 2853, saw 203
# Skipping line 3484: Expected 25 fields in line 3484, saw 26
# Skipping line 7913: Expected 25 fields in line 7913, saw 28
# Skipping line 11857: Expected 25 fields in line 11857, saw 220
# Skipping line 11858: Expected 25 fields in line 11858, saw 220
# Skipping line 19674: Expected 25 fields in line 19674, saw 27
# Skipping line 5767: Expected 25 fields in line 5767, saw 26
# Skipping line 5768: Expected 25 fields in line 5768, saw 26
# Skipping line 5769: Expected 25 fields in line 5769, saw 26
# Skipping line 4240: Expected 25 fields in line 4240, saw 199
# Skipping line 4241: Expected 25 fields in line 4241, saw 221
# Skipping line 4242: Expected 25 fields in line 4242, saw 239
# Skipping line 4243: Expected 25 fields in line 4243, saw 213
# Skipping line 4244: Expected 25 fields in line 4244, saw 190
# Skipping line 4245: Expected 25 fields in line 4245, saw 183
# Skipping line 4246: Expected 25 fields in line 4246, saw 196
# Skipping line 5963: Expected 25 fields in line 5963, saw 67
# Skipping line 11310: Expected 25 fields in line 11310, saw 92
# Skipping line 2805: Expected 25 fields in line 2805, saw 27
# Skipping line 2945: Expected 25 fields in line 2945, saw 27
# Skipping line 7427: Expected 25 fields in line 7427, saw 53
# Skipping line 7428: Expected 25 fields in line 7428, saw 53
# Skipping line 9834: Expected 25 fields in line 9834, saw 39
# Skipping line 13156: Expected 25 fields in line 13156, saw 26
# Skipping line 16968: Expected 25 fields in line 16968, saw 45
# Skipping line 16969: Expected 25 fields in line 16969, saw 45
# Skipping line 5557: Expected 25 fields in line 5557, saw 26
# Skipping line 5558: Expected 25 fields in line 5558, saw 26
# Skipping line 12950: Expected 25 fields in line 12950, saw 32
# Skipping line 4762: Expected 25 fields in line 4762, saw 71
# Skipping line 4763: Expected 25 fields in line 4763, saw 68
# Skipping line 4764: Expected 25 fields in line 4764, saw 71
# Skipping line 4765: Expected 25 fields in line 4765, saw 68
# Skipping line 11969: Expected 25 fields in line 11969, saw 26
# Skipping line 13167: Expected 25 fields in line 13167, saw 26
# Skipping line 14115: Expected 25 fields in line 14115, saw 146
# Skipping line 14116: Expected 25 fields in line 14116, saw 146
# Skipping line 2342: Expected 25 fields in line 2342, saw 65
# Skipping line 2343: Expected 25 fields in line 2343, saw 65
# Skipping line 2344: Expected 25 fields in line 2344, saw 65
# Skipping line 2375: Expected 25 fields in line 2375, saw 76
# Skipping line 2390: Expected 25 fields in line 2390, saw 26
# Skipping line 10113: Expected 25 fields in line 10113, saw 59
# Skipping line 14217: Expected 25 fields in line 14217, saw 51
# Skipping line 2969: Expected 25 fields in line 2969, saw 36
# Skipping line 7451: Expected 25 fields in line 7451, saw 26
# Skipping line 4679: Expected 25 fields in line 4679, saw 53
# Skipping line 24147: Expected 25 fields in line 24147, saw 27
# Skipping line 26904: Expected 25 fields in line 26904, saw 41
# Skipping line 26909: Expected 25 fields in line 26909, saw 41
# Skipping line 27126: Expected 25 fields in line 27126, saw 112
# Skipping line 28547: Expected 25 fields in line 28547, saw 75
# Skipping line 28549: Expected 25 fields in line 28549, saw 75
# Skipping line 28629: Expected 25 fields in line 28629, saw 75
# Skipping line 31933: Expected 25 fields in line 31933, saw 42
# Skipping line 18667: field larger than field limit (131072)
# Skipping line 12994: Expected 25 fields in line 12994, saw 61
# Skipping line 3705: Expected 25 fields in line 3705, saw 48
# Skipping line 14147: Expected 25 fields in line 14147, saw 70
# Skipping line 14151: Expected 25 fields in line 14151, saw 69
# Skipping line 14163: Expected 25 fields in line 14163, saw 69
# Skipping line 14393: Expected 25 fields in line 14393, saw 623
# Skipping line 14647: Expected 25 fields in line 14647, saw 26
# Skipping line 14648: Expected 25 fields in line 14648, saw 26
# Skipping line 14649: Expected 25 fields in line 14649, saw 26
# Skipping line 15050: Expected 25 fields in line 15050, saw 30
# Skipping line 15052: Expected 25 fields in line 15052, saw 30
# Skipping line 2961: Expected 25 fields in line 2961, saw 72
# Skipping line 2962: Expected 25 fields in line 2962, saw 72
# Skipping line 8305: Expected 25 fields in line 8305, saw 57
# Skipping line 9604: Expected 25 fields in line 9604, saw 70
# Skipping line 13615: Expected 25 fields in line 13615, saw 26
# Skipping line 13616: Expected 25 fields in line 13616, saw 26
# Skipping line 7589: field larger than field limit (131072)
# Skipping line 7590: field larger than field limit (131072)
# Skipping line 15846: Expected 25 fields in line 15846, saw 32
# Skipping line 15847: Expected 25 fields in line 15847, saw 32
# Skipping line 16894: Expected 25 fields in line 16894, saw 44
# Skipping line 16895: Expected 25 fields in line 16895, saw 44
# Skipping line 1673: Expected 25 fields in line 1673, saw 36
# Skipping line 2254: Expected 25 fields in line 2254, saw 34
# Skipping line 3646: Expected 25 fields in line 3646, saw 33
# Skipping line 5943: Expected 25 fields in line 5943, saw 73
# Skipping line 5944: Expected 25 fields in line 5944, saw 73
# Skipping line 5945: Expected 25 fields in line 5945, saw 73
# Skipping line 1773: Expected 25 fields in line 1773, saw 47
# Skipping line 1818: Expected 25 fields in line 1818, saw 47
# Skipping line 1819: Expected 25 fields in line 1819, saw 47
# Skipping line 5461: Expected 25 fields in line 5461, saw 92
# Skipping line 5492: Expected 25 fields in line 5492, saw 92
# Skipping line 13079: Expected 25 fields in line 13079, saw 28
# Skipping line 5240: Expected 25 fields in line 5240, saw 71
# Skipping line 10377: field larger than field limit (131072)
# Skipping line 10378: field larger than field limit (131072)
# Skipping line 10591: Expected 25 fields in line 10591, saw 140
# Skipping line 11026: Expected 25 fields in line 11026, saw 33
# Skipping line 11028: Expected 25 fields in line 11028, saw 33
# Skipping line 11029: Expected 25 fields in line 11029, saw 33
# Skipping line 11324: Expected 25 fields in line 11324, saw 33
# Skipping line 10247: field larger than field limit (131072)
# Skipping line 10248: field larger than field limit (131072)
# Skipping line 1785: Expected 25 fields in line 1785, saw 27
# Skipping line 1786: Expected 25 fields in line 1786, saw 27
# Skipping line 4001: Expected 25 fields in line 4001, saw 26
# Skipping line 9213: Expected 25 fields in line 9213, saw 30
# Skipping line 13809: Expected 25 fields in line 13809, saw 53
# Skipping line 2750: Expected 25 fields in line 2750, saw 30
# Skipping line 4360: Expected 25 fields in line 4360, saw 46
# Skipping line 8938: Expected 25 fields in line 8938, saw 376
# Skipping line 8939: Expected 25 fields in line 8939, saw 376
# Skipping line 9769: Expected 25 fields in line 9769, saw 53
# Skipping line 7633: Expected 25 fields in line 7633, saw 29
# Skipping line 7634: Expected 25 fields in line 7634, saw 29
# Skipping line 8952: Expected 25 fields in line 8952, saw 42
# Skipping line 10816: Expected 25 fields in line 10816, saw 31
# Skipping line 11699: Expected 25 fields in line 11699, saw 31
# Skipping line 11701: Expected 25 fields in line 11701, saw 36
# Skipping line 18980: field larger than field limit (131072)
# Skipping line 15282: Expected 25 fields in line 15282, saw 48
# Skipping line 3536: Expected 25 fields in line 3536, saw 50
# Skipping line 3539: Expected 25 fields in line 3539, saw 50
# Skipping line 11197: Expected 25 fields in line 11197, saw 58
# Skipping line 12181: Expected 25 fields in line 12181, saw 29
# Skipping line 12272: Expected 25 fields in line 12272, saw 163
# Skipping line 12273: Expected 25 fields in line 12273, saw 163
# Skipping line 15306: Expected 25 fields in line 15306, saw 120
# Skipping line 15307: Expected 25 fields in line 15307, saw 120
# Skipping line 3512: Expected 25 fields in line 3512, saw 87
# Skipping line 4164: Expected 25 fields in line 4164, saw 32
# Skipping line 4165: Expected 25 fields in line 4165, saw 32
# Skipping line 15902: Expected 25 fields in line 15902, saw 30
# Skipping line 7711: Expected 25 fields in line 7711, saw 53
# Skipping line 7712: Expected 25 fields in line 7712, saw 53
# Skipping line 8703: Expected 25 fields in line 8703, saw 52
# Skipping line 10295: Expected 25 fields in line 10295, saw 39
# Skipping line 10296: Expected 25 fields in line 10296, saw 39
# Skipping line 10356: Expected 25 fields in line 10356, saw 80
# Skipping line 10412: Expected 25 fields in line 10412, saw 83
# Skipping line 10413: Expected 25 fields in line 10413, saw 70
# Skipping line 10414: Expected 25 fields in line 10414, saw 63
# Skipping line 16482: Expected 25 fields in line 16482, saw 76
# Skipping line 16819: Expected 25 fields in line 16819, saw 73
# Skipping line 1164: Expected 25 fields in line 1164, saw 66
# Skipping line 1165: Expected 25 fields in line 1165, saw 66
# Skipping line 2458: Expected 25 fields in line 2458, saw 55
# Skipping line 3967: Expected 25 fields in line 3967, saw 49
# Skipping line 3968: Expected 25 fields in line 3968, saw 49
# Skipping line 3728: Expected 25 fields in line 3728, saw 28
# Skipping line 7387: Expected 25 fields in line 7387, saw 57
# Skipping line 13473: Expected 25 fields in line 13473, saw 233
# Skipping line 13474: Expected 25 fields in line 13474, saw 233
# Skipping line 19621: Expected 25 fields in line 19621, saw 29
# Skipping line 19622: Expected 25 fields in line 19622, saw 29
# Skipping line 35424: Expected 25 fields in line 35424, saw 31
# Skipping line 4409: Expected 25 fields in line 4409, saw 38
# Skipping line 4410: Expected 25 fields in line 4410, saw 30
# Skipping line 4411: Expected 25 fields in line 4411, saw 32
# Skipping line 4412: Expected 25 fields in line 4412, saw 31
# Skipping line 20148: Expected 25 fields in line 20148, saw 52
# Skipping line 10065: Expected 25 fields in line 10065, saw 55
# Skipping line 10066: Expected 25 fields in line 10066, saw 55
# Skipping line 13106: Expected 25 fields in line 13106, saw 26
# Skipping line 13107: Expected 25 fields in line 13107, saw 26
# Skipping line 14690: Expected 25 fields in line 14690, saw 34
# Skipping line 11736: Expected 25 fields in line 11736, saw 70
# Skipping line 12482: Expected 25 fields in line 12482, saw 29
# Skipping line 18903: Expected 25 fields in line 18903, saw 41
# Skipping line 2529: Expected 25 fields in line 2529, saw 80
# Skipping line 2530: Expected 25 fields in line 2530, saw 80
# Skipping line 19358: Expected 25 fields in line 19358, saw 26
# Skipping line 24212: Expected 25 fields in line 24212, saw 42
# Skipping line 24213: Expected 25 fields in line 24213, saw 42
# Skipping line 10077: Expected 25 fields in line 10077, saw 31
# Skipping line 10465: Expected 25 fields in line 10465, saw 61
# Skipping line 3601: Expected 25 fields in line 3601, saw 94
# Skipping line 3602: Expected 25 fields in line 3602, saw 94
# Skipping line 3983: Expected 25 fields in line 3983, saw 49
# Skipping line 17731: Expected 25 fields in line 17731, saw 28
# Skipping line 7468: Expected 25 fields in line 7468, saw 60
# Skipping line 7470: Expected 25 fields in line 7470, saw 60
# Skipping line 11424: Expected 25 fields in line 11424, saw 45
# Skipping line 11427: Expected 25 fields in line 11427, saw 45
# Skipping line 11432: Expected 25 fields in line 11432, saw 45
# Skipping line 14565: Expected 25 fields in line 14565, saw 26
# Skipping line 14566: Expected 25 fields in line 14566, saw 26
# Skipping line 11014: Expected 25 fields in line 11014, saw 112
# Skipping line 11190: Expected 25 fields in line 11190, saw 69
# Skipping line 11191: Expected 25 fields in line 11191, saw 69
# Skipping line 11195: Expected 25 fields in line 11195, saw 67
# Skipping line 12788: Expected 25 fields in line 12788, saw 27
# Skipping line 12903: Expected 25 fields in line 12903, saw 102
# Skipping line 13738: Expected 25 fields in line 13738, saw 63
# Skipping line 2107: Expected 25 fields in line 2107, saw 34
# Skipping line 11351: Expected 25 fields in line 11351, saw 27
# Skipping line 11353: Expected 25 fields in line 11353, saw 27
# Skipping line 15651: Expected 25 fields in line 15651, saw 28
# Skipping line 2055: Expected 25 fields in line 2055, saw 26
# Skipping line 13949: Expected 25 fields in line 13949, saw 45
# Skipping line 13950: Expected 25 fields in line 13950, saw 45
# Skipping line 13958: Expected 25 fields in line 13958, saw 75
# Skipping line 13959: Expected 25 fields in line 13959, saw 75
# Skipping line 13960: Expected 25 fields in line 13960, saw 68
# Skipping line 13961: Expected 25 fields in line 13961, saw 68
# Skipping line 13970: Expected 25 fields in line 13970, saw 144
# Skipping line 13971: Expected 25 fields in line 13971, saw 144
# Skipping line 13988: Expected 25 fields in line 13988, saw 32
# Skipping line 13989: Expected 25 fields in line 13989, saw 32
# Skipping line 13991: Expected 25 fields in line 13991, saw 85
# Skipping line 13992: Expected 25 fields in line 13992, saw 85
# Skipping line 13993: Expected 25 fields in line 13993, saw 76
# Skipping line 13994: Expected 25 fields in line 13994, saw 76
# Skipping line 13999: Expected 25 fields in line 13999, saw 120
# Skipping line 14353: Expected 25 fields in line 14353, saw 129
# Skipping line 14354: Expected 25 fields in line 14354, saw 129
# Skipping line 2698: Expected 25 fields in line 2698, saw 43
# Skipping line 3624: Expected 25 fields in line 3624, saw 52
# Skipping line 3625: Expected 25 fields in line 3625, saw 52
# Skipping line 3669: Expected 25 fields in line 3669, saw 26
# Skipping line 3670: Expected 25 fields in line 3670, saw 26
# Skipping line 8815: Expected 25 fields in line 8815, saw 27
# Skipping line 21386: field larger than field limit (131072)
# Skipping line 2677: Expected 25 fields in line 2677, saw 26
# Skipping line 17737: Expected 25 fields in line 17737, saw 73
# Skipping line 22035: Expected 25 fields in line 22035, saw 26
# Skipping line 4001: Expected 25 fields in line 4001, saw 28
# Skipping line 4002: Expected 25 fields in line 4002, saw 28
# Skipping line 12064: field larger than field limit (131072)
# Skipping line 6097: Expected 25 fields in line 6097, saw 26
# Skipping line 7842: Expected 25 fields in line 7842, saw 37
# Skipping line 12285: Expected 25 fields in line 12285, saw 53
# Skipping line 3722: Expected 25 fields in line 3722, saw 52
# Skipping line 11085: Expected 25 fields in line 11085, saw 29
# Skipping line 12996: Expected 25 fields in line 12996, saw 65
# Skipping line 13035: Expected 25 fields in line 13035, saw 59
# Skipping line 13041: Expected 25 fields in line 13041, saw 67
# Skipping line 25440: Expected 25 fields in line 25440, saw 274
# Skipping line 3603: Expected 25 fields in line 3603, saw 34
# Skipping line 6203: Expected 25 fields in line 6203, saw 34
# Skipping line 8105: Expected 25 fields in line 8105, saw 29
# Skipping line 8106: Expected 25 fields in line 8106, saw 29
# Skipping line 8913: Expected 25 fields in line 8913, saw 122
# Skipping line 8914: Expected 25 fields in line 8914, saw 122
# Skipping line 9007: Expected 25 fields in line 9007, saw 77
# Skipping line 9298: Expected 25 fields in line 9298, saw 53
# Skipping line 9301: Expected 25 fields in line 9301, saw 53
# Skipping line 9304: Expected 25 fields in line 9304, saw 53
# Skipping line 9330: Expected 25 fields in line 9330, saw 51
# Skipping line 14384: Expected 25 fields in line 14384, saw 48
# Skipping line 14385: Expected 25 fields in line 14385, saw 48
# Skipping line 15646: Expected 25 fields in line 15646, saw 37
# Skipping line 15647: Expected 25 fields in line 15647, saw 37

# %%
data = pd.DataFrame(posts, columns=part.columns)
print(data.columns)
print(data.shape)
# Out:
# Index(['post_tags_string', 'post_id', 'activity_time_epoch', 'tumblelog_id',
#        'is_private', 'post_title', 'post_short_url', 'post_slug', 'post_type',
#        'post_caption', 'post_format', 'post_note_count', 'post_tags',
#        'post_content', 'reblogged_from_post_id', 'reblogged_from_metadata',
#        'created_time_epoch', 'updated_time_epoch', 'is_submission', 'mentions',
#        'source_title', 'source_url', 'post_classifier', 'blog_classifier',
#        'activity_date'],
#       dtype='object')
# (23580747, 25)

# %% [markdown]
# ## Remove duplicate posts, non-string posts

# %%
data.drop_duplicates('post_id', inplace=True)
data.shape
# Out:
# (1692294, 25)

# %%
data.dropna(subset=['post_id'], inplace=True)
data.shape
# Out:
# (1692293, 25)

# %%
data = data[data['post_content'].map(lambda x: isinstance(x, str) and len(x) > 0)]
data.shape
# Out:
# (1352536, 25)

# %% [markdown]
# ## Preprocess text

# %%
import re
import spacy

from html.parser import HTMLParser

class MLStripper(HTMLParser):
    def __init__(self):
        super().__init__()
        self.reset()
        self.fed = []
    def handle_data(self, d):
        self.fed.append(d)
    def get_data(self):
        return ' '.join(self.fed)

def strip_tags(html):
    s = MLStripper()
    s.feed(html)
    return s.get_data()

nlp = spacy.load('en', disable=['tagger', 'parser', 'ner'])

def process_text(text):
    """ Extract body of text, preprocess it """
    
    if not isinstance(text, str):
        return ''
    
    m = re.search(r'body=(.*), note_count', text)
    if not m: return ''
    body = m.group(1)
    
    # Strip HTML 
    body = strip_tags(body)
    
    # Tokenize
    toks = [tok.text for tok in nlp.tokenizer(body.lower())]
    
    return ' '.join(toks)

# %%
data['post_body'] = list(map(process_text, tqdm(data['post_content'])))
# Out:
# HBox(children=(IntProgress(value=0, max=1352536), HTML(value='')))

# %%
data = data[data['post_body'].map(lambda x: len(x) > 0)]
data.shape
# Out:
# (575920, 26)

# %% [markdown]
# ## Save out

# %%
data.to_csv(f'../../data/{community}_posts.csv', index=False)

# %% [markdown]
# # Extract stylistic features

# %%
from string import punctuation
from nltk.corpus import words

en_words = set(words.words())
def extract_style_features(text):
    
    features = {}
    
    # Number of words
    toks = text.split()
    n_words = len(toks)
    features['n_words'] = n_words
    features['n_characters'] = len(text)
    
    if n_words == 0: return features
   
    # Number, which punctuation
    total_punctuation = 0
    for p in punctuation:
        p_count = text.count(p)
        features[p] = p_count
        total_punctuation += p_count
    features['avg_punctuation'] = total_punctuation/n_words
    
    # Capitalization
    total_capitals = sum(1 for c in text if c.isupper())
    word_initial_capitals = sum(1 for w in toks if w[0].isupper())
    features['n_capitals'] = total_capitals
    features['avg_capitalized_words'] = word_initial_capitals/n_words
    features['avg_capitalized_letters'] = total_capitals/features['n_characters']
    
    # Out-of-vocabulary words
    features['n_oov'] = sum(1 for w in toks if not w in en_words)
    features['avg_oov'] = features['n_oov']/features['n_words']
    
    # Repeated characters
    total_char_repeats = 0
    for char in set(text):
        repeated_count = text.count(''.join([char]*3))
        if repeated_count > 0:
            features[f'repeated_{char}'] = repeated_count
            total_char_repeats += repeated_count
            
    features['total_char_repeats'] = total_char_repeats
    
    return features

# %%
pd.set_option('display.max_colwidth', -1)

# %%
test = data.loc[1, 'post_content']
test
# Out:
# '{mentions={}, format=html, title=, body=<p>Lance: you just have to be the bigger person and let it go.</p><p>Allura: Okay. *uses her shape shifting power to grow taller* I don?t see how this is supposed to make me want to let it go.</p>, note_count=0, slug=lance-you-just-have-to-be-the-bigger-person-and, tags={(voltron),(allurance),(lallura)}}'

# %%
data['style_features'] = list(map(extract_style_features, tqdm(data['post_body'])))
# Out:
# HBox(children=(IntProgress(value=0, max=575920), HTML(value='')))

# %%
data.to_pickle(f'../../data/{community}_posts.pkl')
